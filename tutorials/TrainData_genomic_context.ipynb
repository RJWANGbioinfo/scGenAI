# %% [markdown]
# # Tutorial: Train single cell data using genomic conext method

# %% [markdown]
# ## Introduction
#
# This tutorial demonstrates how to use **scGenAI** to train a model for predicting cell types from single-cell RNA sequencing (scRNA-seq) data. In this example, we apply the **genomic context** method to generate input sequences.
#
# **Note:**
# 1. The dataset used for this tutorial consists of **40 cells**, selected for demonstration purposes. For practical applications, it is recommended to use a larger, more representative dataset.
# 2. In this tutorial, we will load the model template directly from the cache folder.
# 3. While the model in this example is trained to predict cell types, it can be used to predict any feature in practical applications.

# %% [markdown]
# ## Train the Model Using Genomic Context (Multiple GPU)
#
# The training process can be easily initiated by calling the `run_training_from_config` function in **scGenAI**, using the input files specified in a configuration YAML file. Example template YAML files are available in the `scgenai/examples/config_templates` folder of the package. These templates provide the necessary structure for defining training parameters, model configurations, and input data locations.

# %%
from scGenAI.training.train import run_training_from_config

# %%
config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_genomic_context_template_llama.yaml'
run_training_from_config(config_file)
# Out:
# model_dir: /home/ubuntu/scgenai/examples/testrun/test1/
# train_file: /home/ubuntu/scgenai/examples/data/example_train.h5ad
# val_file: /home/ubuntu/scgenai/examples/data/example_val.h5ad
# cytofile: /home/ubuntu/scgenai/examples/data/GeneSymbol.CytoBand.hg38.tsv
# log_dir: /home/ubuntu/scgenai/examples/logs/
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# cache_dir: /home/ubuntu/scgenai/examples/tmp/cache
# mode: Train
# min_cells: 2
# target_feature: ct
# multiomics: No
# keepIntermediateFiles: No
# savelog: Yes
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: genomic
# num_bins: 10
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 1024
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 20
# world_size: 1
# evaluate_during_training: True
# hidden_size: 256
# num_layers: 6
# num_heads: 4
# intermediate_size: 1024
# stride: 512
# 2024-10-15 21:17:13.560 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-15 21:17:13.562 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# 2024-10-15 21:17:13.566 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-15 21:17:13.569 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# 2024-10-15 21:17:15.790 | INFO     | scGenAI.training.train:model_train_and_eval:214 - Total number of trainable parameters: 74945796; Max Sequence Legth: 512 genes
# Epoch 1/20: 100%|██████████| 44/44 [00:09<00:00,  4.77it/s, GPU_ID=1, train_accuracy=0.477, train_loss=1.15]]
# Epoch 1/20: 100%|██████████| 44/44 [00:09<00:00,  4.77it/s, GPU_ID=0, train_accuracy=0.432, train_loss=1.16]
# Epoch 1/20: 100%|██████████| 44/44 [00:09<00:00,  4.77it/s, GPU_ID=3, train_accuracy=0.659, train_loss=0.937]
# Epoch 1/20: 100%|██████████| 44/44 [00:09<00:00,  4.77it/s, GPU_ID=2, train_accuracy=0.568, train_loss=1.09]
# Evaluating Epoch 1/20: 100%|██████████| 174/174 [00:04<00:00, 38.74it/s]
# Evaluating Epoch 1/20: 100%|██████████| 174/174 [00:04<00:00, 38.64it/s]
# Evaluating Epoch 1/20: 100%|██████████| 174/174 [00:04<00:00, 38.54it/s]
# 2024-10-15 21:17:30.103 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 1/20, Train Loss: 1.1570, Train Accuracy: 0.4318, Context-level Val Loss: 0.8986, Context-level Val Accuracy: 0.5805
# Evaluating Epoch 1/20: 100%|██████████| 174/174 [00:04<00:00, 38.17it/s]
# Epoch 2/20:   0%|          | 0/44 [00:00<?, ?it/s]2024-10-15 21:17:30.677 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:17:30.825 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:17:30.827 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:17:30.828 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 2/20: 100%|██████████| 44/44 [00:09<00:00,  4.72it/s, GPU_ID=3, train_accuracy=0.75, train_loss=0.632]]
#
# Epoch 2/20: 100%|██████████| 44/44 [00:09<00:00,  4.69it/s, GPU_ID=1, train_accuracy=0.614, train_loss=0.855]
# Epoch 2/20: 100%|██████████| 44/44 [00:09<00:00,  4.68it/s, GPU_ID=2, train_accuracy=0.682, train_loss=0.799]
# Evaluating Epoch 2/20: 100%|██████████| 174/174 [00:04<00:00, 38.65it/s]
# Evaluating Epoch 2/20: 100%|██████████| 174/174 [00:04<00:00, 38.63it/s]
# 2024-10-15 21:17:44.043 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 2/20, Train Loss: 0.9444, Train Accuracy: 0.5909, Context-level Val Loss: 0.9144, Context-level Val Accuracy: 0.5805
# Evaluating Epoch 2/20: 100%|██████████| 174/174 [00:04<00:00, 38.49it/s]
# Evaluating Epoch 2/20: 100%|██████████| 174/174 [00:04<00:00, 38.19it/s]
# Epoch 3/20:   0%|          | 0/44 [00:00<?, ?it/s]2024-10-15 21:17:45.873 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:17:46.021 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:17:46.027 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:17:46.028 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 3/20: 100%|██████████| 44/44 [00:08<00:00,  5.05it/s, GPU_ID=0, train_accuracy=0.591, train_loss=0.915]
#
# Epoch 3/20: 100%|██████████| 44/44 [00:10<00:00,  4.16it/s, GPU_ID=3, train_accuracy=0.773, train_loss=0.572]
# Epoch 3/20: 100%|██████████| 44/44 [00:10<00:00,  4.13it/s, GPU_ID=2, train_accuracy=0.705, train_loss=0.741]
# Evaluating Epoch 3/20: 100%|██████████| 174/174 [00:04<00:00, 38.60it/s]
# 2024-10-15 21:17:59.252 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 3/20, Train Loss: 0.9151, Train Accuracy: 0.5909, Context-level Val Loss: 0.9308, Context-level Val Accuracy: 0.5920
# Evaluating Epoch 3/20: 100%|██████████| 174/174 [00:04<00:00, 38.49it/s]
# Evaluating Epoch 3/20: 100%|██████████| 174/174 [00:04<00:00, 38.35it/s]
# Evaluating Epoch 3/20: 100%|██████████| 174/174 [00:04<00:00, 38.05it/s]
# Epoch 4/20:   0%|          | 0/44 [00:00<?, ?it/s]2024-10-15 21:18:01.073 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:18:01.222 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:18:01.224 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:18:01.225 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 4/20: 100%|██████████| 44/44 [00:08<00:00,  5.05it/s, GPU_ID=0, train_accuracy=0.614, train_loss=0.858]
#
#
# Epoch 4/20: 100%|██████████| 44/44 [00:10<00:00,  4.15it/s, GPU_ID=2, train_accuracy=0.727, train_loss=0.642]
# Evaluating Epoch 4/20: 100%|██████████| 174/174 [00:04<00:00, 38.57it/s]
# 2024-10-15 21:18:14.452 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 4/20, Train Loss: 0.8579, Train Accuracy: 0.6136, Context-level Val Loss: 0.9791, Context-level Val Accuracy: 0.5805
# Evaluating Epoch 4/20: 100%|██████████| 174/174 [00:04<00:00, 38.42it/s]
# Evaluating Epoch 4/20: 100%|██████████| 174/174 [00:04<00:00, 38.22it/s]
# Evaluating Epoch 4/20: 100%|██████████| 174/174 [00:04<00:00, 37.68it/s]
# Epoch 5/20: 100%|██████████| 44/44 [00:08<00:00,  5.00it/s, GPU_ID=1, train_accuracy=0.841, train_loss=0.502]
# Epoch 5/20: 100%|██████████| 44/44 [00:08<00:00,  5.04it/s, GPU_ID=3, train_accuracy=0.886, train_loss=0.358]
#
# Epoch 5/20: 100%|██████████| 44/44 [00:08<00:00,  4.99it/s, GPU_ID=2, train_accuracy=0.818, train_loss=0.487]
# Evaluating Epoch 5/20: 100%|██████████| 174/174 [00:04<00:00, 38.39it/s]
# 2024-10-15 21:18:27.880 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 5/20, Train Loss: 0.7193, Train Accuracy: 0.7273, Context-level Val Loss: 0.9983, Context-level Val Accuracy: 0.5690
# Evaluating Epoch 5/20: 100%|██████████| 174/174 [00:04<00:00, 38.30it/s]
# Evaluating Epoch 5/20: 100%|██████████| 174/174 [00:04<00:00, 38.15it/s]
# Evaluating Epoch 5/20: 100%|██████████| 174/174 [00:04<00:00, 37.58it/s]
# Epoch 6/20: 100%|██████████| 44/44 [00:08<00:00,  5.00it/s, GPU_ID=1, train_accuracy=0.932, train_loss=0.31]]
#
# Epoch 6/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=0, train_accuracy=0.886, train_loss=0.437]
# Epoch 6/20: 100%|██████████| 44/44 [00:08<00:00,  4.99it/s, GPU_ID=2, train_accuracy=0.977, train_loss=0.267]
# Evaluating Epoch 6/20: 100%|██████████| 174/174 [00:04<00:00, 38.36it/s]
# 2024-10-15 21:18:41.312 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 6/20, Train Loss: 0.4368, Train Accuracy: 0.8864, Context-level Val Loss: 1.0846, Context-level Val Accuracy: 0.5460
# Evaluating Epoch 6/20: 100%|██████████| 174/174 [00:04<00:00, 38.19it/s]
# Evaluating Epoch 6/20: 100%|██████████| 174/174 [00:04<00:00, 38.05it/s]
# Evaluating Epoch 6/20: 100%|██████████| 174/174 [00:04<00:00, 37.47it/s]
# Epoch 7/20: 100%|██████████| 44/44 [00:08<00:00,  5.04it/s, GPU_ID=3, train_accuracy=0.977, train_loss=0.157]
# Epoch 7/20: 100%|██████████| 44/44 [00:08<00:00,  5.00it/s, GPU_ID=1, train_accuracy=0.977, train_loss=0.143]
# Epoch 7/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=0, train_accuracy=0.932, train_loss=0.257]
#
# Evaluating Epoch 7/20: 100%|██████████| 174/174 [00:04<00:00, 38.31it/s]
# 2024-10-15 21:18:54.758 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 7/20, Train Loss: 0.2566, Train Accuracy: 0.9318, Context-level Val Loss: 1.3052, Context-level Val Accuracy: 0.5230
# Evaluating Epoch 7/20: 100%|██████████| 174/174 [00:04<00:00, 38.08it/s]
# Evaluating Epoch 7/20: 100%|██████████| 174/174 [00:04<00:00, 38.00it/s]
# Evaluating Epoch 7/20: 100%|██████████| 174/174 [00:04<00:00, 37.47it/s]
# Epoch 8/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=0, train_accuracy=0.977, train_loss=0.153]]
#
#
# Epoch 8/20: 100%|██████████| 44/44 [00:08<00:00,  4.99it/s, GPU_ID=2, train_accuracy=1, train_loss=0.085]
# Evaluating Epoch 8/20: 100%|██████████| 174/174 [00:04<00:00, 38.25it/s]
# 2024-10-15 21:19:08.219 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 8/20, Train Loss: 0.1527, Train Accuracy: 0.9773, Context-level Val Loss: 1.2672, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 8/20: 100%|██████████| 174/174 [00:04<00:00, 38.11it/s]
# Evaluating Epoch 8/20: 100%|██████████| 174/174 [00:04<00:00, 37.98it/s]
# Evaluating Epoch 8/20: 100%|██████████| 174/174 [00:04<00:00, 37.39it/s]
# Epoch 9/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0426]
# Epoch 9/20: 100%|██████████| 44/44 [00:08<00:00,  4.99it/s, GPU_ID=1, train_accuracy=1, train_loss=0.036]
# Epoch 9/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0582]
# Epoch 9/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0481]
# Evaluating Epoch 9/20: 100%|██████████| 174/174 [00:04<00:00, 38.18it/s]
# 2024-10-15 21:19:21.690 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 9/20, Train Loss: 0.0582, Train Accuracy: 1.0000, Context-level Val Loss: 1.2803, Context-level Val Accuracy: 0.5575
# Evaluating Epoch 9/20: 100%|██████████| 174/174 [00:04<00:00, 38.01it/s]
# Evaluating Epoch 9/20: 100%|██████████| 174/174 [00:04<00:00, 37.95it/s]
# Evaluating Epoch 9/20: 100%|██████████| 174/174 [00:04<00:00, 37.38it/s]
# Epoch 10/20: 100%|██████████| 44/44 [00:08<00:00,  5.00it/s, GPU_ID=1, train_accuracy=0.977, train_loss=0.081]
# Epoch 10/20: 100%|██████████| 44/44 [00:08<00:00,  5.04it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0251]
# Epoch 10/20: 100%|██████████| 44/44 [00:08<00:00,  4.99it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0247]
# Epoch 10/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=0, train_accuracy=1, train_loss=0.026]
# Evaluating Epoch 10/20: 100%|██████████| 174/174 [00:04<00:00, 38.16it/s]
# 2024-10-15 21:19:35.145 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 10/20, Train Loss: 0.0260, Train Accuracy: 1.0000, Context-level Val Loss: 1.3226, Context-level Val Accuracy: 0.5460
# Evaluating Epoch 10/20: 100%|██████████| 174/174 [00:04<00:00, 38.02it/s]
# Evaluating Epoch 10/20: 100%|██████████| 174/174 [00:04<00:00, 37.96it/s]
# Evaluating Epoch 10/20: 100%|██████████| 174/174 [00:04<00:00, 37.31it/s]
# Epoch 11/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0181]
# Epoch 11/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0186]
# Epoch 11/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0163]
# Epoch 11/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0171]
# Evaluating Epoch 11/20: 100%|██████████| 174/174 [00:04<00:00, 38.11it/s]
# 2024-10-15 21:19:48.631 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 11/20, Train Loss: 0.0181, Train Accuracy: 1.0000, Context-level Val Loss: 1.3651, Context-level Val Accuracy: 0.5460
# Evaluating Epoch 11/20: 100%|██████████| 174/174 [00:04<00:00, 37.95it/s]
# Evaluating Epoch 11/20: 100%|██████████| 174/174 [00:04<00:00, 37.86it/s]
# Evaluating Epoch 11/20: 100%|██████████| 174/174 [00:04<00:00, 37.15it/s]
# Epoch 12/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0126]
# Epoch 12/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.014]
# Epoch 12/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0137]
# Epoch 12/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0136]
# Evaluating Epoch 12/20: 100%|██████████| 174/174 [00:04<00:00, 38.15it/s]
# 2024-10-15 21:20:02.122 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 12/20, Train Loss: 0.0140, Train Accuracy: 1.0000, Context-level Val Loss: 1.4031, Context-level Val Accuracy: 0.5460
# Evaluating Epoch 12/20: 100%|██████████| 174/174 [00:04<00:00, 38.02it/s]
# Evaluating Epoch 12/20: 100%|██████████| 174/174 [00:04<00:00, 37.87it/s]
# Evaluating Epoch 12/20: 100%|██████████| 174/174 [00:04<00:00, 37.11it/s]
# Epoch 13/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0105]
# Epoch 13/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0114]
# Epoch 13/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0116]
# Epoch 13/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0113]
# Evaluating Epoch 13/20: 100%|██████████| 174/174 [00:04<00:00, 38.13it/s]
# 2024-10-15 21:20:15.629 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 13/20, Train Loss: 0.0116, Train Accuracy: 1.0000, Context-level Val Loss: 1.4360, Context-level Val Accuracy: 0.5460
# Evaluating Epoch 13/20: 100%|██████████| 174/174 [00:04<00:00, 37.97it/s]
# Evaluating Epoch 13/20: 100%|██████████| 174/174 [00:04<00:00, 37.85it/s]
# Evaluating Epoch 13/20: 100%|██████████| 174/174 [00:04<00:00, 37.23it/s]
# Epoch 14/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.00894]
# Epoch 14/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00992]
#
# Epoch 14/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00963]
# Evaluating Epoch 14/20: 100%|██████████| 174/174 [00:04<00:00, 38.13it/s]
# 2024-10-15 21:20:29.121 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 14/20, Train Loss: 0.0099, Train Accuracy: 1.0000, Context-level Val Loss: 1.4657, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 14/20: 100%|██████████| 174/174 [00:04<00:00, 37.97it/s]
# Evaluating Epoch 14/20: 100%|██████████| 174/174 [00:04<00:00, 37.84it/s]
# Evaluating Epoch 14/20: 100%|██████████| 174/174 [00:04<00:00, 37.13it/s]
# Epoch 15/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=1, train_accuracy=1, train_loss=0.00848]
# Epoch 15/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00859]
#
# Epoch 15/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00834]
# Evaluating Epoch 15/20: 100%|██████████| 174/174 [00:04<00:00, 38.13it/s]
# 2024-10-15 21:20:42.625 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 15/20, Train Loss: 0.0086, Train Accuracy: 1.0000, Context-level Val Loss: 1.4931, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 15/20: 100%|██████████| 174/174 [00:04<00:00, 37.94it/s]
# Evaluating Epoch 15/20: 100%|██████████| 174/174 [00:04<00:00, 37.80it/s]
# Evaluating Epoch 15/20: 100%|██████████| 174/174 [00:04<00:00, 37.08it/s]
# Epoch 16/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0068]]
# Epoch 16/20: 100%|██████████| 44/44 [00:08<00:00,  4.95it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00753]
# Epoch 16/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=1, train_accuracy=1, train_loss=0.00745]
# Epoch 16/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00731]
# Evaluating Epoch 16/20: 100%|██████████| 174/174 [00:04<00:00, 38.08it/s]
# 2024-10-15 21:20:56.141 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 16/20, Train Loss: 0.0075, Train Accuracy: 1.0000, Context-level Val Loss: 1.5187, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 16/20: 100%|██████████| 174/174 [00:04<00:00, 37.94it/s]
# Evaluating Epoch 16/20: 100%|██████████| 174/174 [00:04<00:00, 37.80it/s]
# Evaluating Epoch 16/20: 100%|██████████| 174/174 [00:04<00:00, 37.11it/s]
# Epoch 17/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.00604]
# Epoch 17/20: 100%|██████████| 44/44 [00:08<00:00,  4.98it/s, GPU_ID=1, train_accuracy=1, train_loss=0.00661]
# Epoch 17/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00666]
# Epoch 17/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00647]
# Evaluating Epoch 17/20: 100%|██████████| 174/174 [00:04<00:00, 38.06it/s]
# 2024-10-15 21:21:09.646 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 17/20, Train Loss: 0.0067, Train Accuracy: 1.0000, Context-level Val Loss: 1.5427, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 17/20: 100%|██████████| 174/174 [00:04<00:00, 37.96it/s]
# Evaluating Epoch 17/20: 100%|██████████| 174/174 [00:04<00:00, 37.80it/s]
# Evaluating Epoch 17/20: 100%|██████████| 174/174 [00:04<00:00, 37.05it/s]
# Epoch 18/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=1, train_accuracy=1, train_loss=0.00592]
#
# Epoch 18/20: 100%|██████████| 44/44 [00:08<00:00,  5.03it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0054]
# Epoch 18/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00578]
# Evaluating Epoch 18/20: 100%|██████████| 174/174 [00:04<00:00, 38.08it/s]
# 2024-10-15 21:21:23.159 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 18/20, Train Loss: 0.0060, Train Accuracy: 1.0000, Context-level Val Loss: 1.5654, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 18/20: 100%|██████████| 174/174 [00:04<00:00, 37.98it/s]
# Evaluating Epoch 18/20: 100%|██████████| 174/174 [00:04<00:00, 37.84it/s]
# Evaluating Epoch 18/20: 100%|██████████| 174/174 [00:04<00:00, 37.11it/s]
# Epoch 19/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00535]
#
# Epoch 19/20: 100%|██████████| 44/44 [00:08<00:00,  5.02it/s, GPU_ID=3, train_accuracy=1, train_loss=0.00487]
# Epoch 19/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00521]
# Evaluating Epoch 19/20: 100%|██████████| 174/174 [00:04<00:00, 38.09it/s]
# 2024-10-15 21:21:36.668 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 19/20, Train Loss: 0.0054, Train Accuracy: 1.0000, Context-level Val Loss: 1.5870, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 19/20: 100%|██████████| 174/174 [00:04<00:00, 37.92it/s]
# Evaluating Epoch 19/20: 100%|██████████| 174/174 [00:04<00:00, 37.79it/s]
# Evaluating Epoch 19/20: 100%|██████████| 174/174 [00:04<00:00, 37.11it/s]
# Epoch 20/20: 100%|██████████| 44/44 [00:08<00:00,  5.02it/s, GPU_ID=3, train_accuracy=1, train_loss=0.00441]
# Epoch 20/20: 100%|██████████| 44/44 [00:08<00:00,  4.96it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00485]
#
# Epoch 20/20: 100%|██████████| 44/44 [00:08<00:00,  4.97it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00471]
# Evaluating Epoch 20/20: 100%|██████████| 174/174 [00:04<00:00, 37.99it/s]
# 2024-10-15 21:21:50.189 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 20/20, Train Loss: 0.0048, Train Accuracy: 1.0000, Context-level Val Loss: 1.6075, Context-level Val Accuracy: 0.5402
# Evaluating Epoch 20/20: 100%|██████████| 174/174 [00:04<00:00, 37.96it/s]
# Evaluating Epoch 20/20: 100%|██████████| 174/174 [00:04<00:00, 37.83it/s]
# Evaluating Epoch 20/20: 100%|██████████| 174/174 [00:04<00:00, 37.09it/s]
# 2024-10-15 21:21:50.766 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model/scGenAI_model.pt
# 2024-10-15 21:21:50.901 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model
# 2024-10-15 21:21:50.904 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:21:50.904 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model
# 2024-10-15 21:21:50.905 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:21:50.905 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:21:50.905 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:21:50.905 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:21:52.132 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 1
# 2024-10-15 21:21:52.227 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 1 - Validation Accuracy: 0.4750
# 2024-10-15 21:21:52.232 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 2
# 2024-10-15 21:21:52.318 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 2 - Validation Accuracy: 0.5500
# 2024-10-15 21:21:52.323 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 3
# 2024-10-15 21:21:52.408 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 3 - Validation Accuracy: 0.6000
# 2024-10-15 21:21:52.413 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 4
# 2024-10-15 21:21:52.498 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 4 - Validation Accuracy: 0.5750
# 2024-10-15 21:21:52.503 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 5
# 2024-10-15 21:21:52.587 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 5 - Validation Accuracy: 0.5750
# 2024-10-15 21:21:52.592 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 6
# 2024-10-15 21:21:52.676 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 6 - Validation Accuracy: 0.5500
# 2024-10-15 21:21:52.681 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 7
# 2024-10-15 21:21:52.765 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 7 - Validation Accuracy: 0.5750
# 2024-10-15 21:21:52.769 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 8
# 2024-10-15 21:21:52.853 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 8 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:52.858 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 9
# 2024-10-15 21:21:52.942 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 9 - Validation Accuracy: 0.6750
# 2024-10-15 21:21:52.946 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 10
# 2024-10-15 21:21:53.031 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 10 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.035 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 11
# 2024-10-15 21:21:53.119 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 11 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.124 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 12
# 2024-10-15 21:21:53.208 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 12 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.213 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 13
# 2024-10-15 21:21:53.297 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 13 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.302 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 14
# 2024-10-15 21:21:53.386 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 14 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.390 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 15
# 2024-10-15 21:21:53.474 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 15 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.479 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 16
# 2024-10-15 21:21:53.563 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 16 - Validation Accuracy: 0.7000
# 2024-10-15 21:21:53.567 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 17
# 2024-10-15 21:21:53.651 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 17 - Validation Accuracy: 0.6750
# 2024-10-15 21:21:53.656 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 18
# 2024-10-15 21:21:53.740 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 18 - Validation Accuracy: 0.6750
# 2024-10-15 21:21:53.744 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 19
# 2024-10-15 21:21:53.829 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 19 - Validation Accuracy: 0.6500
# 2024-10-15 21:21:53.833 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 20
# 2024-10-15 21:21:53.917 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 20 - Validation Accuracy: 0.6500
# 2024-10-15 21:21:53.923 | INFO     | scGenAI.data.postprocess:summarize_epochs:234 - Completed post-processing and summary of all epochs.
# 2024-10-15 21:21:53.926 | INFO     | scGenAI.data.postprocess:combine_epoch_results:61 - Combined results saved to /home/ubuntu/scgenai/examples/testrun/test1/combined_epoch_results.csv.
# Plot saved to /home/ubuntu/scgenai/examples/testrun/test1/train_summary.pdf

# %% [markdown]
# ## Post-Training Model and Results
#
# Upon completion of the training, the trained model will be saved in the `model_dir` as defined in the configuration file. Within this directory, two subfolders will be created: `best_model` and `last_model`. The `best_model` folder contains the model that achieved the highest training performance, while the `last_model` contains the model from the final epoch. Additionally, a `combined_epoch_results.csv` file will be generated in the `model_dir`, summarizing the training performance metrics across all epochs.

# %% [markdown]
# ### Training Summary
#
# In addition to the output summary files generated after training, the training summary can be directly accessed in Python by loading the saved configuration file.

# %%
from scGenAI.config import Config
from scGenAI.data.postprocess import TrainSummary

# %%
config = Config(config_file)
summary = TrainSummary(config.model_dir)
dfsummary = summary.table()
dfsummary
# Out:
#     Epoch  Validation Accuracy  Train Loss  Train Accuracy
# 0       1                0.475    1.157005        0.431818
# 1       2                0.550    0.944430        0.590909
# 2       3                0.600    0.915142        0.590909
# 3       4                0.575    0.857865        0.613636
# 4       5                0.575    0.719339        0.727273
# 5       6                0.550    0.436756        0.886364
# 6       7                0.575    0.256575        0.931818
# 7       8                0.700    0.152656        0.977273
# 8       9                0.675    0.058243        1.000000
# 9      10                0.700    0.026028        1.000000
# 10     11                0.700    0.018078        1.000000
# 11     12                0.700    0.013971        1.000000
# 12     13                0.700    0.011647        1.000000
# 13     14                0.700    0.009921        1.000000
# 14     15                0.700    0.008587        1.000000
# 15     16                0.700    0.007526        1.000000
# 16     17                0.675    0.006664        1.000000
# 17     18                0.675    0.005951        1.000000
# 18     19                0.650    0.005353        1.000000
# 19     20                0.650    0.004845        1.000000

# %% [markdown]
# It can also be plotted using the `summary.plot`:

# %%
summary.plot(saveplot=True)
# Out:
# Plot saved to /home/ubuntu/scgenai/examples/testrun/test1/train_summary.pdf

# %% [markdown]
# ## Prediction Using the Trained Model
#
# Similar to the training step, predictions can be run using the `run_prediction_from_config` function in scGenAI with a simple configuration file. Unlike the training configuration, the prediction configuration file only requires the following parameters to be defined: `mode`, `predict_file`, `batch_size`, `model_dir`, and `outputfile`. All other parameters will be adopted from the trained model.

# %%
from scGenAI.prediction.predict import run_prediction_from_config

# %%
pred_config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_prediction_template.yaml'
run_prediction_from_config(pred_config_file)
# Out:
# model_dir: /home/ubuntu/scgenai/examples/testrun/test1/best_model/
# cytofile: /home/ubuntu/scgenai/examples/testrun/test1/best_model/genomic_context
# predict_file: /home/ubuntu/scgenai/examples/data/example_val.h5ad
# log_dir: /home/ubuntu/scgenai/examples/logs
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# mode: Predict
# min_cells: 2
# multiomics: No
# keepIntermediateFiles: No
# savelog: No
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: genomic
# num_bins: 10
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 1024
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 30
# world_size: 1
# evaluate_during_training: False
# hidden_size: 768
# num_layers: 12
# num_heads: 12
# intermediate_size: 1024
# stride: 512
# 2024-10-15 21:22:48.850 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-15 21:22:48.860 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-15 21:22:48.866 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# 2024-10-15 21:22:48.874 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# GPU 2 Predicting: 100%|██████████| 44/44 [00:01<00:00, 26.90it/s]
# GPU 0 Predicting: 100%|██████████| 44/44 [00:01<00:00, 26.81it/s]
# GPU 3 Predicting: 100%|██████████| 44/44 [00:01<00:00, 26.63it/s]
# GPU 1 Predicting: 100%|██████████| 44/44 [00:01<00:00, 26.49it/s]
# 2024-10-15 21:22:56.601 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:22:56.601 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:22:56.601 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:22:56.601 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:22:57.818 | INFO     | scGenAI.data.postprocess:combine_prediction_results:103 - Completed post-processing for prediction

# %% [markdown]
# The prediction output is a CSV file, as defined in the configuration file. It contains the original metadata extracted from the input prediction file (`obs` slot) along with three additional columns: `context_id`, `PredictedFeature`, and `prediction_score`.
#
# - `context_id` represents the context used to determine the prediction for the corresponding cell.
# - `PredictedFeature` is the final predicted feature for the cell using the trained model.
# - `prediction_score` indicates the confidence level of the prediction, with a maximum value of 1.
#
# For example in this tutorials:

# %%
import pandas as pd
preconfig = Config(pred_config_file)
dfprediction = pd.read_csv(preconfig.outputfile)
dfprediction.head()
# Out:
#                             index     orig.ident  nCount_RNA  nFeature_RNA
# 0  TGCCCTAGTCTTGATG-1--GSM5515744  SeuratProject        2306           871  \
# 1  TGTTCCGGTCACACGC-1--GSM5515744  SeuratProject        1637           665
# 2  TGTCCCAGTTCAGACT-1--GSM5515744  SeuratProject        1935           805
# 3  AACACGTGTGCACGAA-1--GSM5515744  SeuratProject        2053           780
# 4  ATCATGGCAAAGAATC-1--GSM5515744  SeuratProject        1983           788
#
#    RNA_snn_res.0.8  seurat_clusters      sample    sampleId  projectId
# 0               11               11  GSM5515744  GSM5515744  GSE181989  \
# 1                6                6  GSM5515744  GSM5515744  GSE181989
# 2                6                6  GSM5515744  GSM5515744  GSE181989
# 3               25               25  GSM5515744  GSM5515744  GSE181989
# 4                6                6  GSM5515744  GSM5515744  GSE181989
#
#   sampleType  ... subjectId age gender  processStatus
# 0     Normal  ...       NaN NaN    NaN        QC pass  \
# 1     Normal  ...       NaN NaN    NaN        QC pass
# 2     Normal  ...       NaN NaN    NaN        QC pass
# 3     Normal  ...       NaN NaN    NaN        QC pass
# 4     Normal  ...       NaN NaN    NaN        QC pass
#
#          predicted_cell_type                                     ct
# 0              9:granulocyte  Granulocyte-monocyte progenitor (GMP)  \
# 1                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 2                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 3                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 4  4:hematopoietic stem cell  Granulocyte-monocyte progenitor (GMP)
#
#                      cell_barcode                                  context_id
# 0  TGCCCTAGTCTTGATG-1--GSM5515744   0_TGCCCTAGTCTTGATG-1--GSM5515744_window_0  \
# 1  TGTTCCGGTCACACGC-1--GSM5515744   1_TGTTCCGGTCACACGC-1--GSM5515744_window_4
# 2  TGTCCCAGTTCAGACT-1--GSM5515744   2_TGTCCCAGTTCAGACT-1--GSM5515744_window_8
# 3  AACACGTGTGCACGAA-1--GSM5515744  0_AACACGTGTGCACGAA-1--GSM5515744_window_11
# 4  ATCATGGCAAAGAATC-1--GSM5515744  1_ATCATGGCAAAGAATC-1--GSM5515744_window_14
#
#   PredictedFeature prediction_score
# 0     Erythroblast         0.443646
# 1      Granulocyte         0.539907
# 2      Granulocyte         0.527312
# 3     Erythroblast         0.436579
# 4     Erythroblast         0.423584
#
# [5 rows x 23 columns]
