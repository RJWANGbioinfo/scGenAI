# %% [markdown]
# # Tutorial: Train single cell data using genelist method

# %% [markdown]
# ## Introduction
#
# This tutorial demonstrates how to use **scGenAI** to train a model for predicting cell types from single-cell RNA sequencing (scRNA-seq) data. In this example, we apply the **gene list** method to generate input sequences.
#
# **Note:**
# 1. The dataset used for this tutorial consists of **40 cells**, selected for demonstration purposes. For practical applications, it is recommended to use a larger, more representative dataset.
# 2. In this tutorial, we will load the model template directly from the cache folder.
# 3. While the model in this example is trained to predict cell types, it can be used to predict any feature in practical applications.
# 4. In this tutorial, the gene list is built by extracting the top 1000 variable genes from the data, in the practical case, this can be any list that may facilitate the prediction.

# %% [markdown]
# ## Train the Model Using Genelist (Multiple GPU)
#
# The training process can be easily initiated by calling the `run_training_from_config` function in **scGenAI**, using the input files specified in a configuration YAML file. Example template YAML files are available in the `scgenai/examples/config_templates` folder of the package. These templates provide the necessary structure for defining training parameters, model configurations, and input data locations.

# %%
from scGenAI.training.train import run_training_from_config

# %%
config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_genelist_template_llama.yaml'
run_training_from_config(config_file)
# Out:
# model_dir: /home/ubuntu/scgenai/examples/testrun/test1/
# train_file: /home/ubuntu/scgenai/examples/data/example_train.h5ad
# val_file: /home/ubuntu/scgenai/examples/data/example_val.h5ad
# glstfile: /home/ubuntu/scgenai/examples/data/example_variable_genes_TOP1000.txt
# log_dir: /home/ubuntu/scgenai/examples/logs/
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# cache_dir: /home/ubuntu/scgenai/examples/tmp/cache
# mode: Train
# min_cells: 2
# target_feature: ct
# multiomics: No
# keepIntermediateFiles: No
# savelog: Yes
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: genelist
# num_bins: 10
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 2048
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 20
# world_size: 1
# evaluate_during_training: True
# hidden_size: 256
# num_layers: 6
# num_heads: 4
# intermediate_size: 1024
# stride: 1024
# 2024-10-15 21:56:12.745 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-15 21:56:12.746 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# 2024-10-15 21:56:12.750 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# 2024-10-15 21:56:12.751 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-15 21:56:14.922 | INFO     | scGenAI.training.train:model_train_and_eval:214 - Total number of trainable parameters: 72048388; Max Sequence Legth: 1024 genes
# Epoch 1/20: 100%|██████████| 10/10 [00:03<00:00,  3.02it/s, GPU_ID=3, train_accuracy=0.3, train_loss=1.51]
# Epoch 1/20: 100%|██████████| 10/10 [00:03<00:00,  3.02it/s, GPU_ID=2, train_accuracy=0.3, train_loss=1.4]
# Epoch 1/20: 100%|██████████| 10/10 [00:03<00:00,  3.02it/s, GPU_ID=0, train_accuracy=0.1, train_loss=1.57]
# Epoch 1/20: 100%|██████████| 10/10 [00:03<00:00,  3.02it/s, GPU_ID=1, train_accuracy=0.3, train_loss=1.5]
# Evaluating Epoch 1/20: 100%|██████████| 40/40 [00:02<00:00, 17.96it/s]
# Evaluating Epoch 1/20: 100%|██████████| 40/40 [00:02<00:00, 17.75it/s]
# 2024-10-15 21:56:21.053 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 1/20, Train Loss: 1.5740, Train Accuracy: 0.1000, Context-level Val Loss: 1.4455, Context-level Val Accuracy: 0.2500
# Evaluating Epoch 1/20: 100%|██████████| 40/40 [00:02<00:00, 17.73it/s]
# Evaluating Epoch 1/20: 100%|██████████| 40/40 [00:02<00:00, 17.67it/s]
# Epoch 2/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:56:21.577 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:56:21.732 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:56:21.733 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:56:21.733 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 2/20: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, GPU_ID=3, train_accuracy=0.4, train_loss=1.19]
# Epoch 2/20: 100%|██████████| 10/10 [00:02<00:00,  3.58it/s, GPU_ID=0, train_accuracy=0.3, train_loss=1.22]
# Epoch 2/20: 100%|██████████| 10/10 [00:03<00:00,  2.88it/s, GPU_ID=2, train_accuracy=0.5, train_loss=1.2]
# Epoch 2/20: 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, GPU_ID=1, train_accuracy=0.5, train_loss=1.23]
# Evaluating Epoch 2/20: 100%|██████████| 40/40 [00:02<00:00, 17.94it/s]
# Evaluating Epoch 2/20: 100%|██████████| 40/40 [00:02<00:00, 17.77it/s]
# Evaluating Epoch 2/20: 100%|██████████| 40/40 [00:02<00:00, 17.76it/s]
# 2024-10-15 21:56:26.784 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 2/20, Train Loss: 1.2195, Train Accuracy: 0.3000, Context-level Val Loss: 1.3618, Context-level Val Accuracy: 0.2750
# Evaluating Epoch 2/20: 100%|██████████| 40/40 [00:02<00:00, 17.60it/s]
# Epoch 3/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:56:28.475 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:56:28.629 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:56:28.635 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:56:28.636 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 3/20: 100%|██████████| 10/10 [00:04<00:00,  2.15it/s, GPU_ID=2, train_accuracy=0.5, train_loss=1.13]
#
# Epoch 3/20: 100%|██████████| 10/10 [00:02<00:00,  3.57it/s, GPU_ID=0, train_accuracy=0.7, train_loss=1.01]
# Epoch 3/20: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s, GPU_ID=1, train_accuracy=0.7, train_loss=1.11]
# Evaluating Epoch 3/20: 100%|██████████| 40/40 [00:02<00:00, 17.92it/s]
# Evaluating Epoch 3/20: 100%|██████████| 40/40 [00:02<00:00, 17.76it/s]
# Evaluating Epoch 3/20: 100%|██████████| 40/40 [00:02<00:00, 17.70it/s]
# 2024-10-15 21:56:33.697 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 3/20, Train Loss: 1.0067, Train Accuracy: 0.7000, Context-level Val Loss: 1.2516, Context-level Val Accuracy: 0.5000
# Evaluating Epoch 3/20: 100%|██████████| 40/40 [00:02<00:00, 17.53it/s]
# Epoch 4/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:56:35.378 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:56:35.533 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:56:35.536 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:56:35.537 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 4/20: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s, GPU_ID=3, train_accuracy=0.7, train_loss=0.851]
# Epoch 4/20: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s, GPU_ID=2, train_accuracy=0.4, train_loss=1.01]
# Epoch 4/20: 100%|██████████| 10/10 [00:02<00:00,  3.57it/s, GPU_ID=0, train_accuracy=0.7, train_loss=0.796]
# Epoch 4/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=0.9, train_loss=0.927]
# Evaluating Epoch 4/20: 100%|██████████| 40/40 [00:02<00:00, 17.89it/s]
# Evaluating Epoch 4/20: 100%|██████████| 40/40 [00:02<00:00, 17.76it/s]
# 2024-10-15 21:56:40.591 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 4/20, Train Loss: 0.7957, Train Accuracy: 0.7000, Context-level Val Loss: 1.0898, Context-level Val Accuracy: 0.4750
# Evaluating Epoch 4/20: 100%|██████████| 40/40 [00:02<00:00, 17.65it/s]
# Evaluating Epoch 4/20: 100%|██████████| 40/40 [00:02<00:00, 17.63it/s]
# Epoch 5/20: 100%|██████████| 10/10 [00:02<00:00,  3.56it/s, GPU_ID=3, train_accuracy=0.8, train_loss=0.673]
# Epoch 5/20: 100%|██████████| 10/10 [00:02<00:00,  3.52it/s, GPU_ID=2, train_accuracy=0.6, train_loss=0.889]
# Epoch 5/20: 100%|██████████| 10/10 [00:02<00:00,  3.54it/s, GPU_ID=0, train_accuracy=0.7, train_loss=0.633]
# Epoch 5/20: 100%|██████████| 10/10 [00:02<00:00,  3.56it/s, GPU_ID=1, train_accuracy=0.8, train_loss=0.738]
# Evaluating Epoch 5/20: 100%|██████████| 40/40 [00:02<00:00, 17.85it/s]
# Evaluating Epoch 5/20: 100%|██████████| 40/40 [00:02<00:00, 17.76it/s]
# 2024-10-15 21:56:45.696 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 5/20, Train Loss: 0.6332, Train Accuracy: 0.7000, Context-level Val Loss: 0.9584, Context-level Val Accuracy: 0.5250
# Evaluating Epoch 5/20: 100%|██████████| 40/40 [00:02<00:00, 17.67it/s]
# Evaluating Epoch 5/20: 100%|██████████| 40/40 [00:02<00:00, 17.57it/s]
# Epoch 6/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:56:47.374 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:56:47.529 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:56:47.533 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:56:47.534 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 6/20: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s, GPU_ID=2, train_accuracy=0.7, train_loss=0.779]
# Epoch 6/20: 100%|██████████| 10/10 [00:02<00:00,  3.57it/s, GPU_ID=0, train_accuracy=0.7, train_loss=0.527]
#
# Epoch 6/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=0.9, train_loss=0.612]
# Evaluating Epoch 6/20: 100%|██████████| 40/40 [00:02<00:00, 17.84it/s]
# Evaluating Epoch 6/20: 100%|██████████| 40/40 [00:02<00:00, 17.72it/s]
# 2024-10-15 21:56:52.595 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 6/20, Train Loss: 0.5272, Train Accuracy: 0.7000, Context-level Val Loss: 0.8912, Context-level Val Accuracy: 0.5500
# Evaluating Epoch 6/20: 100%|██████████| 40/40 [00:02<00:00, 17.64it/s]
# Evaluating Epoch 6/20: 100%|██████████| 40/40 [00:02<00:00, 17.48it/s]
# Epoch 7/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:56:54.273 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:56:54.437 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:56:54.441 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:56:54.442 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 7/20: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s, GPU_ID=2, train_accuracy=0.8, train_loss=0.67]]
#
# Epoch 7/20: 100%|██████████| 10/10 [00:02<00:00,  3.57it/s, GPU_ID=0, train_accuracy=0.9, train_loss=0.443]
# Epoch 7/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=0.9, train_loss=0.507]
# Evaluating Epoch 7/20: 100%|██████████| 40/40 [00:02<00:00, 17.84it/s]
# Evaluating Epoch 7/20: 100%|██████████| 40/40 [00:02<00:00, 17.72it/s]
# 2024-10-15 21:56:59.506 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 7/20, Train Loss: 0.4432, Train Accuracy: 0.9000, Context-level Val Loss: 0.8534, Context-level Val Accuracy: 0.6000
# Evaluating Epoch 7/20: 100%|██████████| 40/40 [00:02<00:00, 17.63it/s]
# Evaluating Epoch 7/20: 100%|██████████| 40/40 [00:02<00:00, 17.49it/s]
# Epoch 8/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:57:01.188 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:57:01.348 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:57:01.355 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:57:01.356 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 8/20: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s, GPU_ID=3, train_accuracy=1, train_loss=0.305]2]
# Epoch 8/20: 100%|██████████| 10/10 [00:04<00:00,  2.15it/s, GPU_ID=2, train_accuracy=0.9, train_loss=0.542]
# Epoch 8/20: 100%|██████████| 10/10 [00:02<00:00,  3.57it/s, GPU_ID=0, train_accuracy=0.9, train_loss=0.353]
# Epoch 8/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=0.9, train_loss=0.362]
# Evaluating Epoch 8/20: 100%|██████████| 40/40 [00:02<00:00, 17.75it/s]
# Evaluating Epoch 8/20: 100%|██████████| 40/40 [00:02<00:00, 17.72it/s]
# 2024-10-15 21:57:06.419 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 8/20, Train Loss: 0.3533, Train Accuracy: 0.9000, Context-level Val Loss: 0.8390, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 8/20: 100%|██████████| 40/40 [00:02<00:00, 17.56it/s]
# Evaluating Epoch 8/20: 100%|██████████| 40/40 [00:02<00:00, 17.42it/s]
# Epoch 9/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:57:08.104 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:57:08.258 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:57:08.263 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:57:08.264 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 9/20: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s, GPU_ID=3, train_accuracy=1, train_loss=0.223]
# Epoch 9/20: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s, GPU_ID=2, train_accuracy=1, train_loss=0.39]
# Epoch 9/20: 100%|██████████| 10/10 [00:02<00:00,  3.56it/s, GPU_ID=0, train_accuracy=1, train_loss=0.261]
# Epoch 9/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=1, train_loss=0.226]
# Evaluating Epoch 9/20: 100%|██████████| 40/40 [00:02<00:00, 17.78it/s]
# Evaluating Epoch 9/20: 100%|██████████| 40/40 [00:02<00:00, 17.69it/s]
# 2024-10-15 21:57:13.333 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 9/20, Train Loss: 0.2607, Train Accuracy: 1.0000, Context-level Val Loss: 0.8443, Context-level Val Accuracy: 0.7250
# Evaluating Epoch 9/20: 100%|██████████| 40/40 [00:02<00:00, 17.58it/s]
# Evaluating Epoch 9/20: 100%|██████████| 40/40 [00:02<00:00, 17.36it/s]
# Epoch 10/20: 100%|██████████| 10/10 [00:02<00:00,  3.56it/s, GPU_ID=3, train_accuracy=1, train_loss=0.148]
# Epoch 10/20: 100%|██████████| 10/10 [00:02<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=0.172]
# Epoch 10/20: 100%|██████████| 10/10 [00:02<00:00,  3.49it/s, GPU_ID=2, train_accuracy=1, train_loss=0.253]
# Epoch 10/20: 100%|██████████| 10/10 [00:02<00:00,  3.52it/s, GPU_ID=1, train_accuracy=1, train_loss=0.14]
# Evaluating Epoch 10/20: 100%|██████████| 40/40 [00:02<00:00, 17.75it/s]
# Evaluating Epoch 10/20: 100%|██████████| 40/40 [00:02<00:00, 17.68it/s]
# 2024-10-15 21:57:18.481 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 10/20, Train Loss: 0.1716, Train Accuracy: 1.0000, Context-level Val Loss: 0.8151, Context-level Val Accuracy: 0.7250
# Evaluating Epoch 10/20: 100%|██████████| 40/40 [00:02<00:00, 17.50it/s]
# Evaluating Epoch 10/20: 100%|██████████| 40/40 [00:02<00:00, 17.39it/s]
# Epoch 11/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=3, train_accuracy=1, train_loss=0.109]]
# Epoch 11/20: 100%|██████████| 10/10 [00:02<00:00,  3.49it/s, GPU_ID=2, train_accuracy=1, train_loss=0.156]
# Epoch 11/20: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s, GPU_ID=0, train_accuracy=1, train_loss=0.114]
# Epoch 11/20: 100%|██████████| 10/10 [00:02<00:00,  3.54it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0955]
# Evaluating Epoch 11/20: 100%|██████████| 40/40 [00:02<00:00, 17.69it/s]
# Evaluating Epoch 11/20: 100%|██████████| 40/40 [00:02<00:00, 17.68it/s]
# 2024-10-15 21:57:23.625 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 11/20, Train Loss: 0.1145, Train Accuracy: 1.0000, Context-level Val Loss: 0.8054, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 11/20: 100%|██████████| 40/40 [00:02<00:00, 17.52it/s]
# Evaluating Epoch 11/20: 100%|██████████| 40/40 [00:02<00:00, 17.34it/s]
# Epoch 12/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:57:25.308 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:57:25.468 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:57:25.473 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:57:25.474 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 12/20: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0818]
#
# Epoch 12/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0828]
# Epoch 12/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0721]
# Evaluating Epoch 12/20: 100%|██████████| 40/40 [00:02<00:00, 17.72it/s]
# Evaluating Epoch 12/20: 100%|██████████| 40/40 [00:02<00:00, 17.64it/s]
# 2024-10-15 21:57:30.559 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 12/20, Train Loss: 0.0828, Train Accuracy: 1.0000, Context-level Val Loss: 0.8286, Context-level Val Accuracy: 0.7750
# Evaluating Epoch 12/20: 100%|██████████| 40/40 [00:02<00:00, 17.52it/s]
# Evaluating Epoch 12/20: 100%|██████████| 40/40 [00:02<00:00, 17.32it/s]
# Epoch 13/20:   0%|          | 0/10 [00:00<?, ?it/s]2024-10-15 21:57:32.241 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:57:32.393 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:57:32.398 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:57:32.399 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 13/20: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0598]
# Epoch 13/20: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0796]
# Epoch 13/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0623]
# Epoch 13/20: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0599]
# Evaluating Epoch 13/20: 100%|██████████| 40/40 [00:02<00:00, 17.73it/s]
# Evaluating Epoch 13/20: 100%|██████████| 40/40 [00:02<00:00, 17.65it/s]
# 2024-10-15 21:57:37.483 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 13/20, Train Loss: 0.0623, Train Accuracy: 1.0000, Context-level Val Loss: 0.8043, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 13/20: 100%|██████████| 40/40 [00:02<00:00, 17.52it/s]
# Evaluating Epoch 13/20: 100%|██████████| 40/40 [00:02<00:00, 17.35it/s]
# Epoch 14/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0499]
# Epoch 14/20: 100%|██████████| 10/10 [00:02<00:00,  3.49it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0628]
# Epoch 14/20: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0512]
# Epoch 14/20: 100%|██████████| 10/10 [00:02<00:00,  3.52it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0495]
# Evaluating Epoch 14/20: 100%|██████████| 40/40 [00:02<00:00, 17.72it/s]
# Evaluating Epoch 14/20: 100%|██████████| 40/40 [00:02<00:00, 17.63it/s]
# 2024-10-15 21:57:42.635 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 14/20, Train Loss: 0.0512, Train Accuracy: 1.0000, Context-level Val Loss: 0.8019, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 14/20: 100%|██████████| 40/40 [00:02<00:00, 17.51it/s]
# Evaluating Epoch 14/20: 100%|██████████| 40/40 [00:02<00:00, 17.27it/s]
# Epoch 15/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0433]
# Epoch 15/20: 100%|██████████| 10/10 [00:02<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0524]
# Epoch 15/20: 100%|██████████| 10/10 [00:02<00:00,  3.49it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0434]
# Epoch 15/20: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0416]
# Evaluating Epoch 15/20: 100%|██████████| 40/40 [00:02<00:00, 17.70it/s]
# Evaluating Epoch 15/20: 100%|██████████| 40/40 [00:02<00:00, 17.62it/s]
# 2024-10-15 21:57:47.796 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 15/20, Train Loss: 0.0434, Train Accuracy: 1.0000, Context-level Val Loss: 0.7953, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 15/20: 100%|██████████| 40/40 [00:02<00:00, 17.51it/s]
# Evaluating Epoch 15/20: 100%|██████████| 40/40 [00:02<00:00, 17.28it/s]
# Epoch 16/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0369]
# Epoch 16/20: 100%|██████████| 10/10 [00:02<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0416]
# Epoch 16/20: 100%|██████████| 10/10 [00:02<00:00,  3.49it/s, GPU_ID=0, train_accuracy=1, train_loss=0.037]
# Epoch 16/20: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0361]
# Evaluating Epoch 16/20: 100%|██████████| 40/40 [00:02<00:00, 17.67it/s]
# Evaluating Epoch 16/20: 100%|██████████| 40/40 [00:02<00:00, 17.58it/s]
# 2024-10-15 21:57:52.966 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 16/20, Train Loss: 0.0370, Train Accuracy: 1.0000, Context-level Val Loss: 0.8003, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 16/20: 100%|██████████| 40/40 [00:02<00:00, 17.51it/s]
# Evaluating Epoch 16/20: 100%|██████████| 40/40 [00:02<00:00, 17.28it/s]
# Epoch 17/20: 100%|██████████| 10/10 [00:02<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=0.0357]
# Epoch 17/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0328]
# Epoch 17/20: 100%|██████████| 10/10 [00:02<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0325]
# Epoch 17/20: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0314]
# Evaluating Epoch 17/20: 100%|██████████| 40/40 [00:02<00:00, 17.70it/s]
# Evaluating Epoch 17/20: 100%|██████████| 40/40 [00:02<00:00, 17.58it/s]
# 2024-10-15 21:57:58.131 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 17/20, Train Loss: 0.0325, Train Accuracy: 1.0000, Context-level Val Loss: 0.7912, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 17/20: 100%|██████████| 40/40 [00:02<00:00, 17.46it/s]
# Evaluating Epoch 17/20: 100%|██████████| 40/40 [00:02<00:00, 17.26it/s]
# Epoch 18/20: 100%|██████████| 10/10 [00:02<00:00,  3.49it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0289]
#
#
# Epoch 18/20: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0281]
# Evaluating Epoch 18/20: 100%|██████████| 40/40 [00:02<00:00, 17.66it/s]
# Evaluating Epoch 18/20: 100%|██████████| 40/40 [00:02<00:00, 17.55it/s]
# 2024-10-15 21:58:03.301 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 18/20, Train Loss: 0.0289, Train Accuracy: 1.0000, Context-level Val Loss: 0.7936, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 18/20: 100%|██████████| 40/40 [00:02<00:00, 17.43it/s]
# Evaluating Epoch 18/20: 100%|██████████| 40/40 [00:02<00:00, 17.14it/s]
# Epoch 19/20: 100%|██████████| 10/10 [00:02<00:00,  3.54it/s, GPU_ID=3, train_accuracy=1, train_loss=0.0264]
# Epoch 19/20: 100%|██████████| 10/10 [00:02<00:00,  3.47it/s, GPU_ID=0, train_accuracy=1, train_loss=0.026]
#
#
# Evaluating Epoch 19/20: 100%|██████████| 40/40 [00:02<00:00, 17.65it/s]
# Evaluating Epoch 19/20: 100%|██████████| 40/40 [00:02<00:00, 17.59it/s]
# 2024-10-15 21:58:08.483 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 19/20, Train Loss: 0.0260, Train Accuracy: 1.0000, Context-level Val Loss: 0.7882, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 19/20: 100%|██████████| 40/40 [00:02<00:00, 17.45it/s]
# Evaluating Epoch 19/20: 100%|██████████| 40/40 [00:02<00:00, 17.17it/s]
# Epoch 20/20: 100%|██████████| 10/10 [00:02<00:00,  3.48it/s, GPU_ID=0, train_accuracy=1, train_loss=0.0236]
# Epoch 20/20: 100%|██████████| 10/10 [00:02<00:00,  3.55it/s, GPU_ID=3, train_accuracy=1, train_loss=0.024]]
#
# Epoch 20/20: 100%|██████████| 10/10 [00:02<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=0.0231]
# Evaluating Epoch 20/20: 100%|██████████| 40/40 [00:02<00:00, 17.66it/s]
# Evaluating Epoch 20/20: 100%|██████████| 40/40 [00:02<00:00, 17.55it/s]
# 2024-10-15 21:58:13.668 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 20/20, Train Loss: 0.0236, Train Accuracy: 1.0000, Context-level Val Loss: 0.7921, Context-level Val Accuracy: 0.7500
# Evaluating Epoch 20/20: 100%|██████████| 40/40 [00:02<00:00, 17.46it/s]
# Evaluating Epoch 20/20: 100%|██████████| 40/40 [00:02<00:00, 17.16it/s]
# 2024-10-15 21:58:14.192 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model/scGenAI_model.pt
# 2024-10-15 21:58:14.334 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model
# 2024-10-15 21:58:14.335 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:58:14.336 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model
# 2024-10-15 21:58:14.337 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:14.337 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:14.337 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:14.337 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:15.558 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 1
# 2024-10-15 21:58:15.621 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 1 - Validation Accuracy: 0.4250
# 2024-10-15 21:58:15.624 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 2
# 2024-10-15 21:58:15.681 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 2 - Validation Accuracy: 0.3000
# 2024-10-15 21:58:15.683 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 3
# 2024-10-15 21:58:15.737 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 3 - Validation Accuracy: 0.4000
# 2024-10-15 21:58:15.740 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 4
# 2024-10-15 21:58:15.795 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 4 - Validation Accuracy: 0.6000
# 2024-10-15 21:58:15.798 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 5
# 2024-10-15 21:58:15.851 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 5 - Validation Accuracy: 0.5750
# 2024-10-15 21:58:15.854 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 6
# 2024-10-15 21:58:15.909 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 6 - Validation Accuracy: 0.6500
# 2024-10-15 21:58:15.911 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 7
# 2024-10-15 21:58:15.964 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 7 - Validation Accuracy: 0.6750
# 2024-10-15 21:58:15.967 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 8
# 2024-10-15 21:58:16.022 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 8 - Validation Accuracy: 0.7000
# 2024-10-15 21:58:16.024 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 9
# 2024-10-15 21:58:16.078 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 9 - Validation Accuracy: 0.7500
# 2024-10-15 21:58:16.080 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 10
# 2024-10-15 21:58:16.135 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 10 - Validation Accuracy: 0.7750
# 2024-10-15 21:58:16.138 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 11
# 2024-10-15 21:58:16.191 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 11 - Validation Accuracy: 0.7500
# 2024-10-15 21:58:16.193 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 12
# 2024-10-15 21:58:16.248 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 12 - Validation Accuracy: 0.7250
# 2024-10-15 21:58:16.251 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 13
# 2024-10-15 21:58:16.304 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 13 - Validation Accuracy: 0.6750
# 2024-10-15 21:58:16.307 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 14
# 2024-10-15 21:58:16.362 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 14 - Validation Accuracy: 0.6250
# 2024-10-15 21:58:16.364 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 15
# 2024-10-15 21:58:16.417 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 15 - Validation Accuracy: 0.7750
# 2024-10-15 21:58:16.420 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 16
# 2024-10-15 21:58:16.475 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 16 - Validation Accuracy: 0.6750
# 2024-10-15 21:58:16.477 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 17
# 2024-10-15 21:58:16.530 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 17 - Validation Accuracy: 0.6750
# 2024-10-15 21:58:16.533 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 18
# 2024-10-15 21:58:16.588 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 18 - Validation Accuracy: 0.7000
# 2024-10-15 21:58:16.591 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 19
# 2024-10-15 21:58:16.644 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 19 - Validation Accuracy: 0.6750
# 2024-10-15 21:58:16.646 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 20
# 2024-10-15 21:58:16.701 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 20 - Validation Accuracy: 0.6750
# 2024-10-15 21:58:16.705 | INFO     | scGenAI.data.postprocess:summarize_epochs:234 - Completed post-processing and summary of all epochs.
# 2024-10-15 21:58:16.708 | INFO     | scGenAI.data.postprocess:combine_epoch_results:61 - Combined results saved to /home/ubuntu/scgenai/examples/testrun/test1/combined_epoch_results.csv.
# Plot saved to /home/ubuntu/scgenai/examples/testrun/test1/train_summary.pdf

# %% [markdown]
# ## Post-Training Model and Results
#
# Upon completion of the training, the trained model will be saved in the `model_dir` as defined in the configuration file. Within this directory, two subfolders will be created: `best_model` and `last_model`. The `best_model` folder contains the model that achieved the highest training performance, while the `last_model` contains the model from the final epoch. Additionally, a `combined_epoch_results.csv` file will be generated in the `model_dir`, summarizing the training performance metrics across all epochs.

# %% [markdown]
# ### Training Summary
#
# In addition to the output summary files generated after training, the training summary can be directly accessed in Python by loading the saved configuration file.

# %%
from scGenAI.config import Config
from scGenAI.data.postprocess import TrainSummary

# %%
config = Config(config_file)
summary = TrainSummary(config.model_dir)
dfsummary = summary.table()
dfsummary
# Out:
#     Epoch  Validation Accuracy  Train Loss  Train Accuracy
# 0       1                0.425    1.573969             0.1
# 1       2                0.300    1.219471             0.3
# 2       3                0.400    1.006732             0.7
# 3       4                0.600    0.795723             0.7
# 4       5                0.575    0.633211             0.7
# 5       6                0.650    0.527176             0.7
# 6       7                0.675    0.443175             0.9
# 7       8                0.700    0.353277             0.9
# 8       9                0.750    0.260741             1.0
# 9      10                0.775    0.171621             1.0
# 10     11                0.750    0.114454             1.0
# 11     12                0.725    0.082781             1.0
# 12     13                0.675    0.062253             1.0
# 13     14                0.625    0.051208             1.0
# 14     15                0.775    0.043415             1.0
# 15     16                0.675    0.037016             1.0
# 16     17                0.675    0.032464             1.0
# 17     18                0.700    0.028930             1.0
# 18     19                0.675    0.026008             1.0
# 19     20                0.675    0.023576             1.0

# %% [markdown]
# It can also be plotted using the `summary.plot`:

# %%
summary.plot(saveplot=True)
# Out:
# Plot saved to /home/ubuntu/scgenai/examples/testrun/test1/train_summary.pdf

# %% [markdown]
# ## Prediction Using the Trained Model
#
# Similar to the training step, predictions can be run using the `run_prediction_from_config` function in scGenAI with a simple configuration file. Unlike the training configuration, the prediction configuration file only requires the following parameters to be defined: `mode`, `predict_file`, `batch_size`, `model_dir`, and `outputfile`. All other parameters will be adopted from the trained model.

# %%
from scGenAI.prediction.predict import run_prediction_from_config

# %%
pred_config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_prediction_template.yaml'
run_prediction_from_config(pred_config_file)
# Out:
# model_dir: /home/ubuntu/scgenai/examples/testrun/test1/best_model/
# predict_file: /home/ubuntu/scgenai/examples/data/example_val.h5ad
# log_dir: /home/ubuntu/scgenai/examples/logs
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# mode: Predict
# min_cells: 2
# multiomics: No
# keepIntermediateFiles: No
# savelog: No
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: genelist
# num_bins: 10
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 2048
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 30
# world_size: 1
# evaluate_during_training: False
# hidden_size: 768
# num_layers: 12
# num_heads: 12
# intermediate_size: 1024
# stride: 1024
# 2024-10-15 21:58:32.047 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-15 21:58:32.049 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-15 21:58:32.060 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# 2024-10-15 21:58:32.072 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# GPU 0 Predicting: 100%|██████████| 10/10 [00:01<00:00,  9.43it/s]
# GPU 2 Predicting: 100%|██████████| 10/10 [00:01<00:00,  9.43it/s]
# GPU 1 Predicting: 100%|██████████| 10/10 [00:01<00:00,  9.39it/s]
# GPU 3 Predicting: 100%|██████████| 10/10 [00:01<00:00,  9.34it/s]
# 2024-10-15 21:58:36.165 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:36.165 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:36.165 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:36.165 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:58:37.379 | INFO     | scGenAI.data.postprocess:combine_prediction_results:103 - Completed post-processing for prediction

# %% [markdown]
# The prediction output is a CSV file, as defined in the configuration file. It contains the original metadata extracted from the input prediction file (`obs` slot) along with three additional columns: `context_id`, `PredictedFeature`, and `prediction_score`.
#
# - `context_id` represents the context used to determine the prediction for the corresponding cell.
# - `PredictedFeature` is the final predicted feature for the cell using the trained model.
# - `prediction_score` indicates the confidence level of the prediction, with a maximum value of 1.
#
# For example in this tutorials:

# %%
import pandas as pd
preconfig = Config(pred_config_file)
dfprediction = pd.read_csv(preconfig.outputfile)
dfprediction.head()
# Out:
#                             index     orig.ident  nCount_RNA  nFeature_RNA
# 0  TGCCCTAGTCTTGATG-1--GSM5515744  SeuratProject        2306           871  \
# 1  TGTTCCGGTCACACGC-1--GSM5515744  SeuratProject        1637           665
# 2  TGTCCCAGTTCAGACT-1--GSM5515744  SeuratProject        1935           805
# 3  AACACGTGTGCACGAA-1--GSM5515744  SeuratProject        2053           780
# 4  ATCATGGCAAAGAATC-1--GSM5515744  SeuratProject        1983           788
#
#    RNA_snn_res.0.8  seurat_clusters      sample    sampleId  projectId
# 0               11               11  GSM5515744  GSM5515744  GSE181989  \
# 1                6                6  GSM5515744  GSM5515744  GSE181989
# 2                6                6  GSM5515744  GSM5515744  GSE181989
# 3               25               25  GSM5515744  GSM5515744  GSE181989
# 4                6                6  GSM5515744  GSM5515744  GSE181989
#
#   sampleType  ... subjectId age gender  processStatus
# 0     Normal  ...       NaN NaN    NaN        QC pass  \
# 1     Normal  ...       NaN NaN    NaN        QC pass
# 2     Normal  ...       NaN NaN    NaN        QC pass
# 3     Normal  ...       NaN NaN    NaN        QC pass
# 4     Normal  ...       NaN NaN    NaN        QC pass
#
#          predicted_cell_type                                     ct
# 0              9:granulocyte  Granulocyte-monocyte progenitor (GMP)  \
# 1                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 2                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 3                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 4  4:hematopoietic stem cell  Granulocyte-monocyte progenitor (GMP)
#
#                      cell_barcode                                 context_id
# 0  TGCCCTAGTCTTGATG-1--GSM5515744  1_TGCCCTAGTCTTGATG-1--GSM5515744_window_0  \
# 1  TGTTCCGGTCACACGC-1--GSM5515744  3_TGTTCCGGTCACACGC-1--GSM5515744_window_1
# 2  TGTCCCAGTTCAGACT-1--GSM5515744  2_TGTCCCAGTTCAGACT-1--GSM5515744_window_2
# 3  AACACGTGTGCACGAA-1--GSM5515744  2_AACACGTGTGCACGAA-1--GSM5515744_window_3
# 4  ATCATGGCAAAGAATC-1--GSM5515744  0_ATCATGGCAAAGAATC-1--GSM5515744_window_4
#
#                         PredictedFeature prediction_score
# 0                            Granulocyte         0.803131
# 1  Granulocyte-monocyte progenitor (GMP)         0.836315
# 2  Granulocyte-monocyte progenitor (GMP)         0.779462
# 3  Granulocyte-monocyte progenitor (GMP)         0.665145
# 4                            Granulocyte         0.733370
#
# [5 rows x 23 columns]
