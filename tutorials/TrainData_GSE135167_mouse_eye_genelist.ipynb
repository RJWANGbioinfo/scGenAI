# %% [markdown]
# # Tutorial: Train single cell data using genelist method

# %% [markdown]
# ## Introduction
#
# This tutorial demonstrates how to use **scGenAI** to train a model for predicting cell types from single-cell RNA sequencing (scRNA-seq) data. In this example, we apply the **gene list** method to generate input sequences.
#
# **Note:**
# 1. The dataset used for this tutorial is reported in [**Lehmann et. al., 2020**](https://pubmed.ncbi.nlm.nih.gov/32196081/). The input data train and validation files can be downloaded from link of [**GSE135167_mouse_eye_genelist**](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE135167).
# 2. In this tutorial, we will load the model template directly from the cache folder.
# 3. While the model in this example is trained to predict cell types, it can be used to predict any feature in practical applications.
# 4. In this tutorial, the gene list is built by extracting the top 1000 variable genes from the data, in the practical case, this can be any list that may facilitate the prediction.
#
# **Reference**
# 1. Lehmann, G. L., Hanke-Gogokhia, C., Hu, Y., Bareja, R., Salfati, Z., Ginsberg, M., Nolan, D. J., Mendez-Huergo, S. P., Dalotto-Moreno, T., Wojcinski, A., Ochoa, F., Zeng, S., Cerliani, J. P., Panagis, L., Zager, P. J., Mullins, R. F., Ogura, S., Lutty, G. A., Bang, J., Zippin, J. H., … Benedicto, I. (2020). Single-cell profiling reveals an endothelium-mediated immunomodulatory pathway in the eye choroid. The Journal of experimental medicine, 217(6), e20190730. https://doi.org/10.1084/jem.20190730

# %% [markdown]
# ## Train the Model Using Genelist (Multiple GPU)
#
# The training process can be easily initiated by calling the `run_training_from_config` function in **scGenAI**, using the input files specified in a configuration YAML file.

# %%
from scGenAI.training.train import run_training_from_config

# %%
config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_genelist_GSE135167_mouse_eye.yaml'
run_training_from_config(config_file)
# Out:
# model_dir: /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/
# train_file: /home/ubuntu/fulldataset/GSE135167_mouse_eye.train.h5ad
# val_file: /home/ubuntu/fulldataset/GSE135167_mouse_eye.val.h5ad
# glstfile: /home/ubuntu/fulldataset/GSE135167_mouse_eye.highly_variable_genes_TOP1000.txt
# log_dir: /home/ubuntu/fulldataset/logs/
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# cache_dir: /home/ubuntu/scgenai/examples/tmp/cache
# mode: Train
# min_cells: 50
# target_feature: ct
# multiomics: No
# keepIntermediateFiles: Yes
# savelog: Yes
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: genelist
# num_bins: 50
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 2048
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 30
# world_size: 1
# evaluate_during_training: True
# hidden_size: 256
# num_layers: 6
# num_heads: 4
# intermediate_size: 1024
# stride: 1024
# 2024-10-21 17:23:38.349 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-21 17:23:38.355 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-21 17:23:38.364 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# 2024-10-21 17:23:38.365 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# 2024-10-21 17:23:40.556 | INFO     | scGenAI.training.train:model_train_and_eval:214 - Total number of trainable parameters: 72371207; Max Sequence Legth: 1024 genes
# Epoch 1/30: 100%|██████████| 1513/1513 [07:10<00:00,  3.51it/s, GPU_ID=0, train_accuracy=0.862, train_loss=0.451]
# Epoch 1/30: 100%|██████████| 1513/1513 [07:10<00:00,  3.51it/s, GPU_ID=3, train_accuracy=0.873, train_loss=0.409]
# Epoch 1/30: 100%|██████████| 1513/1513 [07:10<00:00,  3.51it/s, GPU_ID=2, train_accuracy=0.857, train_loss=0.435]
# Epoch 1/30: 100%|██████████| 1513/1513 [07:10<00:00,  3.51it/s, GPU_ID=1, train_accuracy=0.853, train_loss=0.455]
# Evaluating Epoch 1/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.15it/s]
# Evaluating Epoch 1/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.09it/s]
# Evaluating Epoch 1/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.83it/s]
# 2024-10-21 17:32:21.953 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 1/30, Train Loss: 0.4506, Train Accuracy: 0.8619, Context-level Val Loss: 0.1340, Context-level Val Accuracy: 0.9564
# Evaluating Epoch 1/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.79it/s]
# Epoch 2/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 17:32:24.671 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 17:32:24.821 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 17:32:24.826 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 17:32:24.827 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 2/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.978, train_loss=0.0776]
#
# Epoch 2/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.971, train_loss=0.0886]
# Epoch 2/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.971, train_loss=0.102]
# Evaluating Epoch 2/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.15it/s]
# Evaluating Epoch 2/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.06it/s]
# Evaluating Epoch 2/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.84it/s]
# 2024-10-21 17:41:06.494 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 2/30, Train Loss: 0.0886, Train Accuracy: 0.9709, Context-level Val Loss: 0.1274, Context-level Val Accuracy: 0.9617
# Evaluating Epoch 2/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.80it/s]
# Epoch 3/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 17:41:09.252 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 17:41:09.403 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 17:41:09.408 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 17:41:09.409 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 3/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.981, train_loss=0.0762]
#
# Epoch 3/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.983, train_loss=0.0517]
# Epoch 3/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.98, train_loss=0.0725]
# Evaluating Epoch 3/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.17it/s]
# Evaluating Epoch 3/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.09it/s]
# Evaluating Epoch 3/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.91it/s]
# 2024-10-21 17:49:50.450 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 3/30, Train Loss: 0.0501, Train Accuracy: 0.9861, Context-level Val Loss: 0.0802, Context-level Val Accuracy: 0.9755
# Evaluating Epoch 3/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.85it/s]
# Epoch 4/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 17:49:53.182 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 17:49:53.332 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 17:49:53.335 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 17:49:53.336 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 4/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.987, train_loss=0.0469]
#
# Epoch 4/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.51it/s, GPU_ID=0, train_accuracy=0.99, train_loss=0.0349]
# Epoch 4/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.984, train_loss=0.0608]
# Evaluating Epoch 4/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.18it/s]
# Evaluating Epoch 4/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.10it/s]
# Evaluating Epoch 4/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.93it/s]
# 2024-10-21 17:58:34.232 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 4/30, Train Loss: 0.0349, Train Accuracy: 0.9901, Context-level Val Loss: 0.0628, Context-level Val Accuracy: 0.9861
# Evaluating Epoch 4/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.81it/s]
# Epoch 5/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 17:58:36.966 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 17:58:37.113 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 17:58:37.117 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 17:58:37.118 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 5/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.51it/s, GPU_ID=0, train_accuracy=0.989, train_loss=0.0286]
#
# Epoch 5/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.984, train_loss=0.0532]
# Epoch 5/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.985, train_loss=0.0426]
# Evaluating Epoch 5/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.17it/s]
# Evaluating Epoch 5/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 5/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.92it/s]
# 2024-10-21 18:07:18.001 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 5/30, Train Loss: 0.0286, Train Accuracy: 0.9894, Context-level Val Loss: 0.0713, Context-level Val Accuracy: 0.9769
# Evaluating Epoch 5/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.78it/s]
# Epoch 6/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=3, train_accuracy=0.992, train_loss=0.0283]
# Epoch 6/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.993, train_loss=0.0255]
# Epoch 6/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=2, train_accuracy=0.989, train_loss=0.0385]
# Epoch 6/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.985, train_loss=0.0487]
# Evaluating Epoch 6/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 6/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.10it/s]
# Evaluating Epoch 6/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.88it/s]
# 2024-10-21 18:16:01.354 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 6/30, Train Loss: 0.0255, Train Accuracy: 0.9927, Context-level Val Loss: 0.0657, Context-level Val Accuracy: 0.9835
# Evaluating Epoch 6/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.77it/s]
# Epoch 7/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=3, train_accuracy=0.993, train_loss=0.0274]
# Epoch 7/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.995, train_loss=0.0148]
# Epoch 7/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=2, train_accuracy=0.99, train_loss=0.0325]
# Epoch 7/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.991, train_loss=0.0273]
# Evaluating Epoch 7/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.16it/s]
# Evaluating Epoch 7/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.04it/s]
# Evaluating Epoch 7/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.87it/s]
# 2024-10-21 18:24:44.508 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 7/30, Train Loss: 0.0148, Train Accuracy: 0.9954, Context-level Val Loss: 0.0816, Context-level Val Accuracy: 0.9822
# Evaluating Epoch 7/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.73it/s]
# Epoch 8/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=3, train_accuracy=0.997, train_loss=0.0104]
# Epoch 8/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.99, train_loss=0.0388]
# Epoch 8/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.993, train_loss=0.0192]
# Epoch 8/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.993, train_loss=0.0199]
# Evaluating Epoch 8/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 8/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.04it/s]
# Evaluating Epoch 8/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.83it/s]
# 2024-10-21 18:33:28.288 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 8/30, Train Loss: 0.0192, Train Accuracy: 0.9927, Context-level Val Loss: 0.0966, Context-level Val Accuracy: 0.9802
# Evaluating Epoch 8/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.78it/s]
# Epoch 9/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=3, train_accuracy=0.991, train_loss=0.0221]
# Epoch 9/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.995, train_loss=0.0137]
# Epoch 9/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=2, train_accuracy=0.996, train_loss=0.0137]
# Epoch 9/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.991, train_loss=0.021]
# Evaluating Epoch 9/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 9/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.05it/s]
# Evaluating Epoch 9/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.85it/s]
# 2024-10-21 18:42:11.428 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 9/30, Train Loss: 0.0137, Train Accuracy: 0.9954, Context-level Val Loss: 0.0828, Context-level Val Accuracy: 0.9868
# Evaluating Epoch 9/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.71it/s]
# Epoch 10/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 18:42:14.148 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 18:42:14.306 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 18:42:14.311 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 18:42:14.312 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 10/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.997, train_loss=0.0169]
# Epoch 10/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.997, train_loss=0.0127]
# Epoch 10/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.996, train_loss=0.0145]
# Epoch 10/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.994, train_loss=0.0234]
# Evaluating Epoch 10/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.14it/s]
# Evaluating Epoch 10/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.04it/s]
# Evaluating Epoch 10/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.85it/s]
# Evaluating Epoch 10/30: 100%|█████████▉| 1506/1513 [01:29<00:00, 16.52it/s]2024-10-21 18:50:55.871 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 10/30, Train Loss: 0.0145, Train Accuracy: 0.9960, Context-level Val Loss: 0.0891, Context-level Val Accuracy: 0.9828
# Evaluating Epoch 10/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.77it/s]
# Epoch 11/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=3, train_accuracy=0.993, train_loss=0.0244]
# Epoch 11/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=2, train_accuracy=0.993, train_loss=0.0297]
# Epoch 11/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.997, train_loss=0.0172]
# Epoch 11/30: 100%|██████████| 1513/1513 [07:11<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.997, train_loss=0.0125]
# Evaluating Epoch 11/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 11/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.02it/s]
# Evaluating Epoch 11/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.83it/s]
# 2024-10-21 18:59:39.063 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 11/30, Train Loss: 0.0172, Train Accuracy: 0.9967, Context-level Val Loss: 0.0669, Context-level Val Accuracy: 0.9868
# Evaluating Epoch 11/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.75it/s]
# Epoch 12/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 18:59:41.794 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 18:59:41.944 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 18:59:41.948 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 18:59:41.949 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 12/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.996, train_loss=0.0138]]
#
# Epoch 12/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.997, train_loss=0.00819]
# Epoch 12/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.997, train_loss=0.00892]
# Evaluating Epoch 12/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 12/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.02it/s]
# Evaluating Epoch 12/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.81it/s]
# 2024-10-21 19:08:24.033 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 12/30, Train Loss: 0.0082, Train Accuracy: 0.9974, Context-level Val Loss: 0.0818, Context-level Val Accuracy: 0.9874
# Evaluating Epoch 12/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.69it/s]
# Epoch 13/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 19:08:26.732 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 19:08:26.882 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 19:08:26.887 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 19:08:26.888 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 13/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=2, train_accuracy=0.997, train_loss=0.0103]]
#
# Epoch 13/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.999, train_loss=0.00952]
# Epoch 13/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.994, train_loss=0.0198]
# Evaluating Epoch 13/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.08it/s]
# Evaluating Epoch 13/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.96it/s]
# Evaluating Epoch 13/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.76it/s]
# 2024-10-21 19:17:09.580 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 13/30, Train Loss: 0.0095, Train Accuracy: 0.9987, Context-level Val Loss: 0.0834, Context-level Val Accuracy: 0.9868
# Evaluating Epoch 13/30: 100%|██████████| 1513/1513 [01:31<00:00, 16.62it/s]
# Epoch 14/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.999, train_loss=0.00676]
# Epoch 14/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=0, train_accuracy=0.995, train_loss=0.0224]]
#
# Epoch 14/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.999, train_loss=0.00671]
# Evaluating Epoch 14/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 14/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.06it/s]
# Evaluating Epoch 14/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.83it/s]
# 2024-10-21 19:25:53.627 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 14/30, Train Loss: 0.0224, Train Accuracy: 0.9954, Context-level Val Loss: 0.0609, Context-level Val Accuracy: 0.9861
# Evaluating Epoch 14/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.65it/s]
# Epoch 15/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.999, train_loss=0.00119]
# Epoch 15/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=0, train_accuracy=0.995, train_loss=0.0168]
# Epoch 15/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.996, train_loss=0.0203]
# Epoch 15/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.998, train_loss=0.00499]
# Evaluating Epoch 15/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 15/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.00it/s]
# Evaluating Epoch 15/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.78it/s]
# 2024-10-21 19:34:38.043 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 15/30, Train Loss: 0.0168, Train Accuracy: 0.9954, Context-level Val Loss: 0.0645, Context-level Val Accuracy: 0.9901
# Evaluating Epoch 15/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.68it/s]
# Epoch 16/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 19:34:40.768 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 19:34:40.928 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 19:34:40.932 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 19:34:40.933 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 16/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=3, train_accuracy=1, train_loss=0.000245]47]
# Epoch 16/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=2, train_accuracy=0.999, train_loss=0.00225]
#
# Epoch 16/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.999, train_loss=0.00447]
# Evaluating Epoch 16/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.15it/s]
# Evaluating Epoch 16/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.02it/s]
# Evaluating Epoch 16/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.81it/s]
# 2024-10-21 19:43:23.163 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 16/30, Train Loss: 0.0048, Train Accuracy: 0.9993, Context-level Val Loss: 0.0770, Context-level Val Accuracy: 0.9888
# Evaluating Epoch 16/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.71it/s]
# Epoch 17/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=3, train_accuracy=1, train_loss=0.000571]]8]
# Epoch 17/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00057]388]
#
# Epoch 17/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.997, train_loss=0.011]
# Evaluating Epoch 17/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 17/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.06it/s]
# Evaluating Epoch 17/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.83it/s]
# 2024-10-21 19:52:06.786 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 17/30, Train Loss: 0.0006, Train Accuracy: 1.0000, Context-level Val Loss: 0.0681, Context-level Val Accuracy: 0.9894
# Evaluating Epoch 17/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.69it/s]
# Epoch 18/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.49it/s, GPU_ID=0, train_accuracy=1, train_loss=0.000128]5]
# Epoch 18/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=6.83e-5]
#
# Epoch 18/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.999, train_loss=0.0125]
# Evaluating Epoch 18/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.14it/s]
# Evaluating Epoch 18/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.03it/s]
# Evaluating Epoch 18/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.80it/s]
# 2024-10-21 20:00:50.902 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 18/30, Train Loss: 0.0001, Train Accuracy: 1.0000, Context-level Val Loss: 0.0664, Context-level Val Accuracy: 0.9907
# Evaluating Epoch 18/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.67it/s]
# Epoch 19/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 20:00:53.634 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 20:00:53.782 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 20:00:53.787 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 20:00:53.788 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 19/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.994, train_loss=0.0217]
# Epoch 19/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=0.997, train_loss=0.0141]
# Epoch 19/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=2, train_accuracy=0.995, train_loss=0.0181]
# Epoch 19/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=0.994, train_loss=0.0205]
# Evaluating Epoch 19/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.14it/s]
# Evaluating Epoch 19/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.02it/s]
# Evaluating Epoch 19/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.81it/s]
# 2024-10-21 20:09:36.013 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 19/30, Train Loss: 0.0141, Train Accuracy: 0.9974, Context-level Val Loss: 0.0991, Context-level Val Accuracy: 0.9855
# Evaluating Epoch 19/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.70it/s]
# Epoch 20/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=0.999, train_loss=0.00647]
# Epoch 20/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=0.997, train_loss=0.0121]]
#
# Epoch 20/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=0.997, train_loss=0.0133]
# Evaluating Epoch 20/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 20/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.03it/s]
# Evaluating Epoch 20/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.79it/s]
# 2024-10-21 20:18:20.256 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 20/30, Train Loss: 0.0058, Train Accuracy: 0.9987, Context-level Val Loss: 0.0490, Context-level Val Accuracy: 0.9907
# Evaluating Epoch 20/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.68it/s]
# Epoch 21/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 20:18:22.978 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 20:18:23.136 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 20:18:23.141 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 20:18:23.141 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 21/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=0.000123]
#
# Epoch 21/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=3, train_accuracy=1, train_loss=0.000289]
# Epoch 21/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=1, train_loss=0.000246]
# Evaluating Epoch 21/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.11it/s]
# Evaluating Epoch 21/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.01it/s]
# Evaluating Epoch 21/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.79it/s]
# 2024-10-21 20:27:05.774 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 21/30, Train Loss: 0.0001, Train Accuracy: 1.0000, Context-level Val Loss: 0.0488, Context-level Val Accuracy: 0.9914
# Evaluating Epoch 21/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.65it/s]
# Epoch 22/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 20:27:08.509 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 20:27:08.657 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 20:27:08.661 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 20:27:08.662 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 22/30: 100%|██████████| 1513/1513 [07:16<00:00,  3.47it/s, GPU_ID=2, train_accuracy=1, train_loss=6.84e-5]]
#
# Epoch 22/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=0.000158]
# Epoch 22/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=1, train_loss=6.5e-5]
# Evaluating Epoch 22/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 22/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.01it/s]
# Evaluating Epoch 22/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.79it/s]
# 2024-10-21 20:35:51.370 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 22/30, Train Loss: 0.0002, Train Accuracy: 1.0000, Context-level Val Loss: 0.0548, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 22/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.65it/s]
# Epoch 23/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 20:35:54.101 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 20:35:54.261 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 20:35:54.265 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 20:35:54.266 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 23/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=3.32e-5]
# Epoch 23/30: 100%|██████████| 1513/1513 [07:16<00:00,  3.47it/s, GPU_ID=2, train_accuracy=1, train_loss=2.8e-5]
# Epoch 23/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=3, train_accuracy=1, train_loss=2.61e-5]
# Epoch 23/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=1, train_loss=2.58e-5]
# Evaluating Epoch 23/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 23/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.03it/s]
# Evaluating Epoch 23/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.79it/s]
# 2024-10-21 20:44:36.799 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 23/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0566, Context-level Val Accuracy: 0.9934
# Evaluating Epoch 23/30: 100%|██████████| 1513/1513 [01:31<00:00, 16.61it/s]
# Epoch 24/30:   0%|          | 0/1513 [00:00<?, ?it/s]2024-10-21 20:44:39.530 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/scGenAI_model.pt
# 2024-10-21 20:44:39.679 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# 2024-10-21 20:44:39.684 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 20:44:39.685 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model
# Epoch 24/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=3, train_accuracy=1, train_loss=1.51e-5]
# Epoch 24/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.47it/s, GPU_ID=2, train_accuracy=1, train_loss=1.59e-5]
# Epoch 24/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=1.77e-5]
# Epoch 24/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=1, train_accuracy=1, train_loss=1.44e-5]
# Evaluating Epoch 24/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 24/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.02it/s]
# Evaluating Epoch 24/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.80it/s]
# 2024-10-21 20:53:22.028 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 24/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0580, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 24/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.69it/s]
# Epoch 25/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.49it/s, GPU_ID=3, train_accuracy=1, train_loss=8.95e-6]
# Epoch 25/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=0, train_accuracy=1, train_loss=9.71e-6]
#
# Epoch 25/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=8.38e-6]
# Evaluating Epoch 25/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 25/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.03it/s]
# Evaluating Epoch 25/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.82it/s]
# 2024-10-21 21:02:05.848 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 25/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0596, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 25/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.65it/s]
# Epoch 26/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=1, train_loss=5.08e-6]
# Epoch 26/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=5.24e-6]
#
# Epoch 26/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=4.82e-6]
# Evaluating Epoch 26/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 26/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.07it/s]
# Evaluating Epoch 26/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.83it/s]
# 2024-10-21 21:10:50.023 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 26/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0616, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 26/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.67it/s]
# Epoch 27/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=1, train_loss=2.75e-6]
# Epoch 27/30: 100%|██████████| 1513/1513 [07:13<00:00,  3.49it/s, GPU_ID=0, train_accuracy=1, train_loss=2.8e-6]
# Epoch 27/30: 100%|██████████| 1513/1513 [07:15<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=2.82e-6]
# Epoch 27/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=2.67e-6]
# Evaluating Epoch 27/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 27/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.01it/s]
# Evaluating Epoch 27/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.80it/s]
# 2024-10-21 21:19:34.506 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 27/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0640, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 27/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.70it/s]
# Epoch 28/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.49it/s, GPU_ID=3, train_accuracy=1, train_loss=1.41e-6]
# Epoch 28/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=1.46e-6]
#
# Epoch 28/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=1.42e-6]
# Evaluating Epoch 28/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.11it/s]
# Evaluating Epoch 28/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.05it/s]
# Evaluating Epoch 28/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.80it/s]
# 2024-10-21 21:28:18.515 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 28/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0668, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 28/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.71it/s]
# Epoch 29/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=7.41e-7]
# Epoch 29/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=3, train_accuracy=1, train_loss=7.16e-7]
# Epoch 29/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.49it/s, GPU_ID=0, train_accuracy=1, train_loss=7.39e-7]
# Epoch 29/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=7.37e-7]
# Evaluating Epoch 29/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.12it/s]
# Evaluating Epoch 29/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.04it/s]
# Evaluating Epoch 29/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.80it/s]
# 2024-10-21 21:37:02.592 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 29/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0699, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 29/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.70it/s]
# Epoch 30/30: 100%|██████████| 1513/1513 [07:14<00:00,  3.48it/s, GPU_ID=2, train_accuracy=1, train_loss=3.71e-7]
#
#
# Epoch 30/30: 100%|██████████| 1513/1513 [07:12<00:00,  3.50it/s, GPU_ID=1, train_accuracy=1, train_loss=3.76e-7]
# Evaluating Epoch 30/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.13it/s]
# Evaluating Epoch 30/30: 100%|██████████| 1513/1513 [01:28<00:00, 17.06it/s]
# Evaluating Epoch 30/30: 100%|██████████| 1513/1513 [01:29<00:00, 16.82it/s]
# 2024-10-21 21:45:46.531 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 30/30, Train Loss: 0.0000, Train Accuracy: 1.0000, Context-level Val Loss: 0.0731, Context-level Val Accuracy: 0.9927
# Evaluating Epoch 30/30: 100%|██████████| 1513/1513 [01:30<00:00, 16.70it/s]
# 2024-10-21 21:45:48.093 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/last_model/scGenAI_model.pt
# 2024-10-21 21:45:48.230 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/last_model
# 2024-10-21 21:45:48.231 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-21 21:45:48.232 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/last_model
# 2024-10-21 21:45:48.264 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-21 21:45:48.264 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-21 21:45:48.264 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-21 21:45:48.264 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-21 21:45:50.312 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 1
# 2024-10-21 21:45:52.404 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 1 - Validation Accuracy: 0.9551
# 2024-10-21 21:45:52.517 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 2
# 2024-10-21 21:45:54.615 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 2 - Validation Accuracy: 0.9564
# 2024-10-21 21:45:54.728 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 3
# 2024-10-21 21:45:56.820 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 3 - Validation Accuracy: 0.9676
# 2024-10-21 21:45:56.933 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 4
# 2024-10-21 21:45:59.026 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 4 - Validation Accuracy: 0.9788
# 2024-10-21 21:45:59.139 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 5
# 2024-10-21 21:46:01.223 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 5 - Validation Accuracy: 0.9722
# 2024-10-21 21:46:01.335 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 6
# 2024-10-21 21:46:03.406 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 6 - Validation Accuracy: 0.9841
# 2024-10-21 21:46:03.519 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 7
# 2024-10-21 21:46:05.578 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 7 - Validation Accuracy: 0.9815
# 2024-10-21 21:46:05.691 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 8
# 2024-10-21 21:46:07.736 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 8 - Validation Accuracy: 0.9762
# 2024-10-21 21:46:07.848 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 9
# 2024-10-21 21:46:10.058 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 9 - Validation Accuracy: 0.9835
# 2024-10-21 21:46:10.169 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 10
# 2024-10-21 21:46:12.191 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 10 - Validation Accuracy: 0.9802
# 2024-10-21 21:46:12.302 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 11
# 2024-10-21 21:46:14.310 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 11 - Validation Accuracy: 0.9861
# 2024-10-21 21:46:14.421 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 12
# 2024-10-21 21:46:16.417 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 12 - Validation Accuracy: 0.9868
# 2024-10-21 21:46:16.528 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 13
# 2024-10-21 21:46:18.511 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 13 - Validation Accuracy: 0.9861
# 2024-10-21 21:46:18.622 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 14
# 2024-10-21 21:46:20.676 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 14 - Validation Accuracy: 0.9868
# 2024-10-21 21:46:20.786 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 15
# 2024-10-21 21:46:22.852 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 15 - Validation Accuracy: 0.9901
# 2024-10-21 21:46:22.962 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 16
# 2024-10-21 21:46:25.027 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 16 - Validation Accuracy: 0.9874
# 2024-10-21 21:46:25.137 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 17
# 2024-10-21 21:46:27.199 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 17 - Validation Accuracy: 0.9888
# 2024-10-21 21:46:27.309 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 18
# 2024-10-21 21:46:29.366 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 18 - Validation Accuracy: 0.9888
# 2024-10-21 21:46:29.475 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 19
# 2024-10-21 21:46:31.519 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 19 - Validation Accuracy: 0.9835
# 2024-10-21 21:46:31.628 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 20
# 2024-10-21 21:46:33.658 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 20 - Validation Accuracy: 0.9894
# 2024-10-21 21:46:33.768 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 21
# 2024-10-21 21:46:35.791 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 21 - Validation Accuracy: 0.9907
# 2024-10-21 21:46:35.900 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 22
# 2024-10-21 21:46:37.904 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 22 - Validation Accuracy: 0.9921
# 2024-10-21 21:46:38.013 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 23
# 2024-10-21 21:46:40.005 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 23 - Validation Accuracy: 0.9921
# 2024-10-21 21:46:40.114 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 24
# 2024-10-21 21:46:42.092 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 24 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:42.201 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 25
# 2024-10-21 21:46:44.167 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 25 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:44.275 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 26
# 2024-10-21 21:46:46.314 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 26 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:46.423 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 27
# 2024-10-21 21:46:48.472 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 27 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:48.580 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 28
# 2024-10-21 21:46:50.849 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 28 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:50.957 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 29
# 2024-10-21 21:46:53.003 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 29 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:53.111 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 30
# 2024-10-21 21:46:55.156 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 30 - Validation Accuracy: 0.9927
# 2024-10-21 21:46:55.266 | INFO     | scGenAI.data.postprocess:summarize_epochs:234 - Completed post-processing and summary of all epochs.
# 2024-10-21 21:46:55.269 | INFO     | scGenAI.data.postprocess:combine_epoch_results:61 - Combined results saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/combined_epoch_results.csv.
# Plot saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/train_summary.pdf

# %% [markdown]
# ## Post-Training Model and Results
#
# Upon completion of the training, the trained model will be saved in the `model_dir` as defined in the configuration file. Within this directory, two subfolders will be created: `best_model` and `last_model`. The `best_model` folder contains the model that achieved the highest training performance, while the `last_model` contains the model from the final epoch. Additionally, a `combined_epoch_results.csv` file will be generated in the `model_dir`, summarizing the training performance metrics across all epochs.

# %% [markdown]
# ### Training Summary
#
# In addition to the output summary files generated after training, the training summary can be directly accessed in Python by loading the saved configuration file.

# %%
from scGenAI.config import Config
from scGenAI.data.postprocess import TrainSummary

# %%
config = Config(config_file)
summary = TrainSummary(config.model_dir)
dfsummary = summary.table()
dfsummary
# Out:
#     Epoch  Validation Accuracy    Train Loss  Train Accuracy
# 0       1             0.955056  4.505679e-01        0.861864
# 1       2             0.956378  8.856105e-02        0.970919
# 2       3             0.967614  5.010466e-02        0.986120
# 3       4             0.978850  3.490974e-02        0.990086
# 4       5             0.972241  2.856238e-02        0.989425
# 5       6             0.984137  2.545965e-02        0.992730
# 6       7             0.981494  1.477643e-02        0.995373
# 7       8             0.976206  1.924984e-02        0.992730
# 8       9             0.983477  1.367687e-02        0.995373
# 9      10             0.980172  1.445226e-02        0.996034
# 10     11             0.986120  1.719473e-02        0.996695
# 11     12             0.986781  8.187722e-03        0.997356
# 12     13             0.986120  9.515192e-03        0.998678
# 13     14             0.986781  2.240826e-02        0.995373
# 14     15             0.990086  1.679708e-02        0.995373
# 15     16             0.987442  4.841243e-03        0.999339
# 16     17             0.988764  5.704443e-04        1.000000
# 17     18             0.988764  1.283778e-04        1.000000
# 18     19             0.983477  1.407412e-02        0.997356
# 19     20             0.989425  5.786440e-03        0.998678
# 20     21             0.990747  1.227286e-04        1.000000
# 21     22             0.992069  1.578189e-04        1.000000
# 22     23             0.992069  3.316078e-05        1.000000
# 23     24             0.992730  1.770001e-05        1.000000
# 24     25             0.992730  9.713663e-06        1.000000
# 25     26             0.992730  5.290310e-06        1.000000
# 26     27             0.992730  2.798589e-06        1.000000
# 27     28             0.992730  1.438855e-06        1.000000
# 28     29             0.992730  7.387332e-07        1.000000
# 29     30             0.992730  3.640094e-07        1.000000

# %% [markdown]
# It can also be plotted using the `summary.plot`:

# %%
summary.plot(saveplot=True)
# Out:
# Plot saved to /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/train_summary.pdf

# %% [markdown]
# ## Prediction Using the Trained Model
#
# Similar to the training step, predictions can be run using the `run_prediction_from_config` function in scGenAI with a simple configuration file. Unlike the training configuration, the prediction configuration file only requires the following parameters to be defined: `mode`, `predict_file`, `batch_size`, `model_dir`, and `outputfile`. All other parameters will be adopted from the trained model.

# %%
from scGenAI.prediction.predict import run_prediction_from_config

# %%
pred_config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_prediction_GSE135167_mouse_eye.yaml'
run_prediction_from_config(pred_config_file)
# Out:
# model_dir: /home/ubuntu/fulldataset/model/GSE135167_mouse_eye_topp1kgenes/best_model/
# predict_file: /home/ubuntu/fulldataset/GSE135167_mouse_eye.val.h5ad
# log_dir: /home/ubuntu/scgenai/examples/logs
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# mode: Predict
# min_cells: 50
# multiomics: No
# keepIntermediateFiles: Yes
# savelog: No
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: genelist
# num_bins: 50
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 2048
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 30
# world_size: 1
# evaluate_during_training: False
# hidden_size: 768
# num_layers: 12
# num_heads: 12
# intermediate_size: 1024
# stride: 1024
# 2024-10-22 00:23:36.958 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-22 00:23:36.962 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-22 00:23:36.970 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# 2024-10-22 00:23:36.996 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# GPU 2 Predicting: 100%|██████████| 379/379 [00:21<00:00, 17.36it/s]
# GPU 0 Predicting: 100%|██████████| 379/379 [00:22<00:00, 17.17it/s]
# GPU 3 Predicting: 100%|██████████| 379/379 [00:22<00:00, 17.16it/s]
# GPU 1 Predicting: 100%|██████████| 379/379 [00:22<00:00, 17.01it/s]
# 2024-10-22 00:24:02.912 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-22 00:24:02.912 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-22 00:24:02.912 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-22 00:24:02.912 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-22 00:24:04.295 | INFO     | scGenAI.data.postprocess:combine_prediction_results:103 - Completed post-processing for prediction

# %% [markdown]
# The prediction output is a CSV file, as defined in the configuration file. It contains the original metadata extracted from the input prediction file (`obs` slot) along with three additional columns: `context_id`, `PredictedFeature`, and `prediction_score`.
#
# - `context_id` represents the context used to determine the prediction for the corresponding cell.
# - `PredictedFeature` is the final predicted feature for the cell using the trained model.
# - `prediction_score` indicates the confidence level of the prediction, with a maximum value of 1.
#
# For example in this tutorials:

# %%
import pandas as pd
preconfig = Config(pred_config_file)
dfprediction = pd.read_csv(preconfig.outputfile)
dfprediction.head()
# Out:
#                      index orig.ident conditions  var.ratio.pca  res.0.8
# 0      B6_CGATTGATCTTCAACT         B6         B6       0.973345        3  \
# 1      B6_CCGGGATAGCTAAACA         B6         B6       1.007342        7
# 2      B6_AACGTTGCAAGCGAGT         B6         B6       1.003478        3
# 3      B6_CCTACACAGCTAGCCC         B6         B6       0.969138        1
# 4  129_B6_GGGCATCCATTCGACA        129     129_B6       0.964243        1
#
#    percent.mito  ClusterNames_0.8           Cell.types  nCount_RNA
# 0      0.023335                 9  Smooth muscle cells        2057  \
# 1      0.024749                 8        Stromal cells        5374
# 2      0.022488                 9  Smooth muscle cells        2846
# 3      0.031937                 6        Stromal cells        4415
# 4      0.033408                 6        Stromal cells        4879
#
#    nFeature_RNA                   ct             cell_barcode
# 0           951  Smooth muscle cells      B6_CGATTGATCTTCAACT  \
# 1          2296        Stromal cells      B6_CCGGGATAGCTAAACA
# 2          1322  Smooth muscle cells      B6_AACGTTGCAAGCGAGT
# 3          1933        Stromal cells      B6_CCTACACAGCTAGCCC
# 4          2022        Stromal cells  129_B6_GGGCATCCATTCGACA
#
#                            context_id     PredictedFeature  prediction_score
# 0      3_B6_CGATTGATCTTCAACT_window_0  Smooth muscle cells          0.999994
# 1      0_B6_CCGGGATAGCTAAACA_window_1        Stromal cells          0.999985
# 2      1_B6_AACGTTGCAAGCGAGT_window_2  Smooth muscle cells          0.999985
# 3      2_B6_CCTACACAGCTAGCCC_window_3        Stromal cells          0.999987
# 4  1_129_B6_GGGCATCCATTCGACA_window_4        Stromal cells          0.999987
