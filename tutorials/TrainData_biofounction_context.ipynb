# %% [markdown]
# # Tutorial: Train single cell data using biofounction conext method

# %% [markdown]
# ## Introduction
#
# This tutorial demonstrates how to use **scGenAI** to train a model for predicting cell types from single-cell RNA sequencing (scRNA-seq) data. In this example, we apply the **biofounction context** method to generate input sequences.
#
# **Note:**
# 1. The dataset used for this tutorial consists of **40 cells**, selected for demonstration purposes. For practical applications, it is recommended to use a larger, more representative dataset.
# 2. In this tutorial, we will load the model template directly from the cache folder.
# 3. While the model in this example is trained to predict cell types, it can be used to predict any feature in practical applications.

# %% [markdown]
# ## Train the Model Using Biofounction Context (Multiple GPU)
#
# The training process can be easily initiated by calling the `run_training_from_config` function in **scGenAI**, using the input files specified in a configuration YAML file. Example template YAML files are available in the `scgenai/examples/config_templates` folder of the package. These templates provide the necessary structure for defining training parameters, model configurations, and input data locations.

# %%
from scGenAI.training.train import run_training_from_config

# %%
config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_biofounction_context_template_llama.yaml'
run_training_from_config(config_file)
# Out:
# model_dir: /home/ubuntu/scgenai/examples/testrun/test1/
# train_file: /home/ubuntu/scgenai/examples/data/example_train.h5ad
# val_file: /home/ubuntu/scgenai/examples/data/example_val.h5ad
# gmtfile: /home/ubuntu/scgenai/examples/data/c8.BONE_MARROW.v2023.2.Hs.symbols.gmt
# log_dir: /home/ubuntu/scgenai/examples/logs/
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# cache_dir: /home/ubuntu/scgenai/examples/tmp/cache
# mode: Train
# min_cells: 2
# target_feature: ct
# multiomics: No
# keepIntermediateFiles: No
# savelog: Yes
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: biofounction
# num_bins: 10
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 1024
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 20
# world_size: 1
# evaluate_during_training: True
# hidden_size: 256
# num_layers: 6
# num_heads: 4
# intermediate_size: 1024
# stride: 512
# Processed 40/40 cells
# 2024-10-15 21:38:52.693 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-15 21:38:52.700 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# 2024-10-15 21:38:52.707 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# 2024-10-15 21:38:52.708 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-15 21:38:54.957 | INFO     | scGenAI.training.train:model_train_and_eval:214 - Total number of trainable parameters: 74945796; Max Sequence Legth: 512 genes
# Epoch 1/20: 100%|██████████| 46/46 [00:09<00:00,  4.78it/s, GPU_ID=0, train_accuracy=0.587, train_loss=1.05]]
# Epoch 1/20: 100%|██████████| 46/46 [00:09<00:00,  4.78it/s, GPU_ID=1, train_accuracy=0.565, train_loss=0.898]
#
# Epoch 1/20: 100%|██████████| 46/46 [00:09<00:00,  4.78it/s, GPU_ID=2, train_accuracy=0.543, train_loss=1.16]
# Evaluating Epoch 1/20: 100%|██████████| 184/184 [00:04<00:00, 38.78it/s]
# Evaluating Epoch 1/20: 100%|██████████| 184/184 [00:04<00:00, 38.69it/s]
# Evaluating Epoch 1/20: 100%|██████████| 184/184 [00:04<00:00, 38.69it/s]
# 2024-10-15 21:39:09.901 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 1/20, Train Loss: 1.0489, Train Accuracy: 0.5870, Context-level Val Loss: 0.8362, Context-level Val Accuracy: 0.6467
# Evaluating Epoch 1/20: 100%|██████████| 184/184 [00:04<00:00, 38.30it/s]
# Epoch 2/20:   0%|          | 0/46 [00:00<?, ?it/s]2024-10-15 21:39:10.474 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:39:10.625 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:39:10.628 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:39:10.629 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 2/20: 100%|██████████| 46/46 [00:09<00:00,  4.71it/s, GPU_ID=1, train_accuracy=0.761, train_loss=0.595]
# Epoch 2/20: 100%|██████████| 46/46 [00:09<00:00,  4.73it/s, GPU_ID=3, train_accuracy=0.696, train_loss=0.708]
# Epoch 2/20: 100%|██████████| 46/46 [00:09<00:00,  5.05it/s, GPU_ID=0, train_accuracy=0.739, train_loss=0.769]
# Epoch 2/20: 100%|██████████| 46/46 [00:09<00:00,  4.70it/s, GPU_ID=2, train_accuracy=0.63, train_loss=0.906]
# Evaluating Epoch 2/20: 100%|██████████| 184/184 [00:04<00:00, 38.68it/s]
# 2024-10-15 21:39:24.492 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 2/20, Train Loss: 0.7693, Train Accuracy: 0.7391, Context-level Val Loss: 0.8166, Context-level Val Accuracy: 0.6467
# Evaluating Epoch 2/20: 100%|██████████| 184/184 [00:04<00:00, 38.63it/s]
# Evaluating Epoch 2/20: 100%|██████████| 184/184 [00:04<00:00, 38.47it/s]
# Evaluating Epoch 2/20: 100%|██████████| 184/184 [00:04<00:00, 38.36it/s]
# Epoch 3/20:   0%|          | 0/46 [00:00<?, ?it/s]2024-10-15 21:39:26.313 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:39:26.473 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:39:26.476 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:39:26.477 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 3/20: 100%|██████████| 46/46 [00:11<00:00,  4.18it/s, GPU_ID=1, train_accuracy=0.804, train_loss=0.527]
#
# Epoch 3/20: 100%|██████████| 46/46 [00:10<00:00,  4.18it/s, GPU_ID=3, train_accuracy=0.739, train_loss=0.654]
# Epoch 3/20: 100%|██████████| 46/46 [00:11<00:00,  4.17it/s, GPU_ID=2, train_accuracy=0.696, train_loss=0.809]
# Evaluating Epoch 3/20: 100%|██████████| 184/184 [00:04<00:00, 38.68it/s]
# 2024-10-15 21:39:40.347 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 3/20, Train Loss: 0.7049, Train Accuracy: 0.7174, Context-level Val Loss: 0.8217, Context-level Val Accuracy: 0.6685
# Evaluating Epoch 3/20: 100%|██████████| 184/184 [00:04<00:00, 38.53it/s]
# Evaluating Epoch 3/20: 100%|██████████| 184/184 [00:04<00:00, 38.38it/s]
# Evaluating Epoch 3/20: 100%|██████████| 184/184 [00:04<00:00, 37.97it/s]
# Epoch 4/20:   0%|          | 0/46 [00:00<?, ?it/s]2024-10-15 21:39:42.180 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model/scGenAI_model.pt
# 2024-10-15 21:39:42.335 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# 2024-10-15 21:39:42.341 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:39:42.342 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/best_model
# Epoch 4/20: 100%|██████████| 46/46 [00:09<00:00,  5.05it/s, GPU_ID=0, train_accuracy=0.739, train_loss=0.643]
# Epoch 4/20: 100%|██████████| 46/46 [00:11<00:00,  4.18it/s, GPU_ID=1, train_accuracy=0.848, train_loss=0.428]
# Epoch 4/20: 100%|██████████| 46/46 [00:10<00:00,  4.20it/s, GPU_ID=3, train_accuracy=0.761, train_loss=0.57]
# Epoch 4/20: 100%|██████████| 46/46 [00:11<00:00,  4.17it/s, GPU_ID=2, train_accuracy=0.761, train_loss=0.714]
# Evaluating Epoch 4/20: 100%|██████████| 184/184 [00:04<00:00, 38.59it/s]
# 2024-10-15 21:39:56.223 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 4/20, Train Loss: 0.6435, Train Accuracy: 0.7391, Context-level Val Loss: 0.8327, Context-level Val Accuracy: 0.6467
# Evaluating Epoch 4/20: 100%|██████████| 184/184 [00:04<00:00, 38.41it/s]
# Evaluating Epoch 4/20: 100%|██████████| 184/184 [00:04<00:00, 38.24it/s]
# Evaluating Epoch 4/20: 100%|██████████| 184/184 [00:04<00:00, 37.84it/s]
# Epoch 5/20: 100%|██████████| 46/46 [00:09<00:00,  5.01it/s, GPU_ID=1, train_accuracy=0.848, train_loss=0.305]
# Epoch 5/20: 100%|██████████| 46/46 [00:09<00:00,  4.99it/s, GPU_ID=0, train_accuracy=0.804, train_loss=0.532]
# Epoch 5/20: 100%|██████████| 46/46 [00:09<00:00,  5.04it/s, GPU_ID=3, train_accuracy=0.848, train_loss=0.448]
# Evaluating Epoch 19/20: 100%|██████████| 184/184 [00:04<00:00, 37.85it/s]
# Evaluating Epoch 19/20: 100%|██████████| 184/184 [00:04<00:00, 37.13it/s]
# Epoch 20/20: 100%|██████████| 46/46 [00:09<00:00,  4.97it/s, GPU_ID=1, train_accuracy=1, train_loss=0.00422]
# Epoch 20/20: 100%|██████████| 46/46 [00:09<00:00,  4.95it/s, GPU_ID=0, train_accuracy=1, train_loss=0.00458]
# Epoch 20/20: 100%|██████████| 46/46 [00:09<00:00,  5.02it/s, GPU_ID=3, train_accuracy=1, train_loss=0.00449]
# Epoch 20/20: 100%|██████████| 46/46 [00:09<00:00,  4.96it/s, GPU_ID=2, train_accuracy=1, train_loss=0.00471]
# Evaluating Epoch 20/20: 100%|██████████| 184/184 [00:04<00:00, 38.18it/s]
# 2024-10-15 21:43:42.368 | INFO     | scGenAI.training.train:evaluate_and_save_predictions:328 - Epoch 20/20, Train Loss: 0.0046, Train Accuracy: 1.0000, Context-level Val Loss: 1.1455, Context-level Val Accuracy: 0.6413
# Evaluating Epoch 20/20: 100%|██████████| 184/184 [00:04<00:00, 38.00it/s]
# Evaluating Epoch 20/20: 100%|██████████| 184/184 [00:04<00:00, 37.83it/s]
# Evaluating Epoch 20/20: 100%|██████████| 184/184 [00:04<00:00, 37.07it/s]
# 2024-10-15 21:43:42.943 | INFO     | scGenAI.utils.distributed:savemodel:54 - Model state saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model/scGenAI_model.pt
# 2024-10-15 21:43:43.086 | INFO     | scGenAI.utils.distributed:savemodel:59 - Tokenizer saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model
# 2024-10-15 21:43:43.088 | INFO     | scGenAI.utils.distributed:savemodel:75 - Custom vocab and label encoder saved
# 2024-10-15 21:43:43.089 | INFO     | scGenAI.utils.distributed:savemodel:81 - Model configuration saved to /home/ubuntu/scgenai/examples/testrun/test1/last_model
# 2024-10-15 21:43:43.090 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:43:43.090 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:43:43.090 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:43:43.090 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:43:44.315 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 1
# 2024-10-15 21:43:44.418 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 1 - Validation Accuracy: 0.4500
# 2024-10-15 21:43:44.423 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 2
# 2024-10-15 21:43:44.515 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 2 - Validation Accuracy: 0.4250
# 2024-10-15 21:43:44.521 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 3
# 2024-10-15 21:43:44.611 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 3 - Validation Accuracy: 0.5000
# 2024-10-15 21:43:44.616 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 4
# 2024-10-15 21:43:44.706 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 4 - Validation Accuracy: 0.4750
# 2024-10-15 21:43:44.711 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 5
# 2024-10-15 21:43:44.800 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 5 - Validation Accuracy: 0.4500
# 2024-10-15 21:43:44.805 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 6
# 2024-10-15 21:43:44.896 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 6 - Validation Accuracy: 0.4750
# 2024-10-15 21:43:44.901 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 7
# 2024-10-15 21:43:44.990 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 7 - Validation Accuracy: 0.4750
# 2024-10-15 21:43:44.995 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 8
# 2024-10-15 21:43:45.085 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 8 - Validation Accuracy: 0.5000
# 2024-10-15 21:43:45.090 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 9
# 2024-10-15 21:43:45.179 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 9 - Validation Accuracy: 0.4750
# 2024-10-15 21:43:45.184 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 10
# 2024-10-15 21:43:45.271 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 10 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:45.276 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 11
# 2024-10-15 21:43:45.363 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 11 - Validation Accuracy: 0.5750
# 2024-10-15 21:43:45.368 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 12
# 2024-10-15 21:43:45.455 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 12 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:45.460 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 13
# 2024-10-15 21:43:45.549 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 13 - Validation Accuracy: 0.5250
# 2024-10-15 21:43:45.554 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 14
# 2024-10-15 21:43:45.642 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 14 - Validation Accuracy: 0.5250
# 2024-10-15 21:43:45.647 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 15
# 2024-10-15 21:43:45.736 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 15 - Validation Accuracy: 0.5250
# 2024-10-15 21:43:45.741 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 16
# 2024-10-15 21:43:45.829 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 16 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:45.834 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 17
# 2024-10-15 21:43:45.921 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 17 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:45.926 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 18
# 2024-10-15 21:43:46.013 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 18 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:46.018 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 19
# 2024-10-15 21:43:46.106 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 19 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:46.111 | INFO     | scGenAI.data.postprocess:merge_predictions_across_gpus:147 - Merging predictions for epoch 20
# 2024-10-15 21:43:46.198 | INFO     | scGenAI.data.postprocess:postprocess_epoch:211 - Epoch 20 - Validation Accuracy: 0.5500
# 2024-10-15 21:43:46.204 | INFO     | scGenAI.data.postprocess:summarize_epochs:234 - Completed post-processing and summary of all epochs.
# 2024-10-15 21:43:46.207 | INFO     | scGenAI.data.postprocess:combine_epoch_results:61 - Combined results saved to /home/ubuntu/scgenai/examples/testrun/test1/combined_epoch_results.csv.
# Plot saved to /home/ubuntu/scgenai/examples/testrun/test1/train_summary.pdf

# %% [markdown]
# ## Post-Training Model and Results
#
# Upon completion of the training, the trained model will be saved in the `model_dir` as defined in the configuration file. Within this directory, two subfolders will be created: `best_model` and `last_model`. The `best_model` folder contains the model that achieved the highest training performance, while the `last_model` contains the model from the final epoch. Additionally, a `combined_epoch_results.csv` file will be generated in the `model_dir`, summarizing the training performance metrics across all epochs.

# %% [markdown]
# ### Training Summary
#
# In addition to the output summary files generated after training, the training summary can be directly accessed in Python by loading the saved configuration file.

# %%
from scGenAI.config import Config
from scGenAI.data.postprocess import TrainSummary

# %%
config = Config(config_file)
summary = TrainSummary(config.model_dir)
dfsummary = summary.table()
dfsummary
# Out:
#     Epoch  Validation Accuracy  Train Loss  Train Accuracy
# 0       1                0.450    1.048929        0.586957
# 1       2                0.425    0.769282        0.739130
# 2       3                0.500    0.704915        0.717391
# 3       4                0.475    0.643454        0.739130
# 4       5                0.450    0.531550        0.804348
# 5       6                0.475    0.349914        0.891304
# 6       7                0.475    0.179244        0.978261
# 7       8                0.500    0.091448        1.000000
# 8       9                0.475    0.047549        1.000000
# 9      10                0.550    0.032353        1.000000
# 10     11                0.575    0.020925        1.000000
# 11     12                0.550    0.017287        1.000000
# 12     13                0.525    0.012231        1.000000
# 13     14                0.525    0.009602        1.000000
# 14     15                0.525    0.008264        1.000000
# 15     16                0.550    0.007202        1.000000
# 16     17                0.550    0.006351        1.000000
# 17     18                0.550    0.005655        1.000000
# 18     19                0.550    0.005074        1.000000
# 19     20                0.550    0.004585        1.000000

# %% [markdown]
# It can also be plotted using the `summary.plot`:

# %%
summary.plot(saveplot=True)
# Out:
# Plot saved to /home/ubuntu/scgenai/examples/testrun/test1/train_summary.pdf

# %% [markdown]
# ## Prediction Using the Trained Model
#
# Similar to the training step, predictions can be run using the `run_prediction_from_config` function in scGenAI with a simple configuration file. Unlike the training configuration, the prediction configuration file only requires the following parameters to be defined: `mode`, `predict_file`, `batch_size`, `model_dir`, and `outputfile`. All other parameters will be adopted from the trained model.

# %%
from scGenAI.prediction.predict import run_prediction_from_config

# %%
pred_config_file = '/home/ubuntu/scgenai/tutorials/yaml/config_prediction_template.yaml'
run_prediction_from_config(pred_config_file)
# Out:
# model_dir: /home/ubuntu/scgenai/examples/testrun/test1/best_model/
# gmtfile: /home/ubuntu/scgenai/examples/testrun/test1/best_model/biofounction_context
# predict_file: /home/ubuntu/scgenai/examples/data/example_val.h5ad
# log_dir: /home/ubuntu/scgenai/examples/logs
# output_dir: /home/ubuntu/scgenai/examples/output
# seed: 1314521
# mode: Predict
# min_cells: 2
# multiomics: No
# keepIntermediateFiles: No
# savelog: No
# savesetting: Yes
# model_backbone_name: llama
# model_backbone_size: small
# context_method: biofounction
# num_bins: 10
# optimizer: AdamW
# weight_decay: 0.01
# depth: 2
# max_length: 1024
# batch_size: 1
# learning_rate: 1e-05
# num_epochs: 30
# world_size: 1
# evaluate_during_training: False
# hidden_size: 768
# num_layers: 12
# num_heads: 12
# intermediate_size: 1024
# stride: 512
# 2024-10-15 21:45:34.194 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 3, Total GPUs used: 4
# 2024-10-15 21:45:34.199 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 0, Total GPUs used: 4
# 2024-10-15 21:45:34.206 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 2, Total GPUs used: 4
# 2024-10-15 21:45:34.210 | INFO     | scGenAI.utils.distributed:setup_distributed:26 - Distributed setup complete for GPU 1, Total GPUs used: 4
# Processed 40/40 cells
# GPU 2 Predicting: 100%|██████████| 46/46 [00:01<00:00, 27.32it/s]
# GPU 1 Predicting: 100%|██████████| 46/46 [00:01<00:00, 27.30it/s]
# GPU 0 Predicting: 100%|██████████| 46/46 [00:01<00:00, 27.28it/s]
# GPU 3 Predicting: 100%|██████████| 46/46 [00:01<00:00, 27.25it/s]
# 2024-10-15 21:45:42.891 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:45:42.891 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:45:42.891 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:45:42.891 | INFO     | scGenAI.utils.distributed:cleanup:33 - Cleaned up DDP environment
# 2024-10-15 21:45:44.084 | INFO     | scGenAI.data.postprocess:combine_prediction_results:103 - Completed post-processing for prediction

# %% [markdown]
# The prediction output is a CSV file, as defined in the configuration file. It contains the original metadata extracted from the input prediction file (`obs` slot) along with three additional columns: `context_id`, `PredictedFeature`, and `prediction_score`.
#
# - `context_id` represents the context used to determine the prediction for the corresponding cell.
# - `PredictedFeature` is the final predicted feature for the cell using the trained model.
# - `prediction_score` indicates the confidence level of the prediction, with a maximum value of 1.
#
# For example in this tutorials:

# %%
import pandas as pd
preconfig = Config(pred_config_file)
dfprediction = pd.read_csv(preconfig.outputfile)
dfprediction.head()
# Out:
#                             index     orig.ident  nCount_RNA  nFeature_RNA
# 0  TGCCCTAGTCTTGATG-1--GSM5515744  SeuratProject        2306           871  \
# 1  TGTTCCGGTCACACGC-1--GSM5515744  SeuratProject        1637           665
# 2  TGTCCCAGTTCAGACT-1--GSM5515744  SeuratProject        1935           805
# 3  AACACGTGTGCACGAA-1--GSM5515744  SeuratProject        2053           780
# 4  ATCATGGCAAAGAATC-1--GSM5515744  SeuratProject        1983           788
#
#    RNA_snn_res.0.8  seurat_clusters      sample    sampleId  projectId
# 0               11               11  GSM5515744  GSM5515744  GSE181989  \
# 1                6                6  GSM5515744  GSM5515744  GSE181989
# 2                6                6  GSM5515744  GSM5515744  GSE181989
# 3               25               25  GSM5515744  GSM5515744  GSE181989
# 4                6                6  GSM5515744  GSM5515744  GSE181989
#
#   sampleType  ... subjectId age gender  processStatus
# 0     Normal  ...       NaN NaN    NaN        QC pass  \
# 1     Normal  ...       NaN NaN    NaN        QC pass
# 2     Normal  ...       NaN NaN    NaN        QC pass
# 3     Normal  ...       NaN NaN    NaN        QC pass
# 4     Normal  ...       NaN NaN    NaN        QC pass
#
#          predicted_cell_type                                     ct
# 0              9:granulocyte  Granulocyte-monocyte progenitor (GMP)  \
# 1                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 2                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 3                    13:cDC2  Granulocyte-monocyte progenitor (GMP)
# 4  4:hematopoietic stem cell  Granulocyte-monocyte progenitor (GMP)
#
#                      cell_barcode
# 0  TGCCCTAGTCTTGATG-1--GSM5515744  \
# 1  TGTTCCGGTCACACGC-1--GSM5515744
# 2  TGTCCCAGTTCAGACT-1--GSM5515744
# 3  AACACGTGTGCACGAA-1--GSM5515744
# 4  ATCATGGCAAAGAATC-1--GSM5515744
#
#                                           context_id
# 0  1_TGCCCTAGTCTTGATG-1--GSM5515744_window_DENDRI...  \
# 1  3_TGTTCCGGTCACACGC-1--GSM5515744_window_MONOCY...
# 2  0_TGTCCCAGTTCAGACT-1--GSM5515744_window_CD34_T...
# 3          3_AACACGTGTGCACGAA-1--GSM5515744_window_0
# 4  2_ATCATGGCAAAGAATC-1--GSM5515744_window_ERYTHR...
#
#                         PredictedFeature prediction_score
# 0  Granulocyte-monocyte progenitor (GMP)         0.610014
# 1  Granulocyte-monocyte progenitor (GMP)         0.504304
# 2  Granulocyte-monocyte progenitor (GMP)         0.533765
# 3  Granulocyte-monocyte progenitor (GMP)         0.435774
# 4  Granulocyte-monocyte progenitor (GMP)         0.411171
#
# [5 rows x 23 columns]
